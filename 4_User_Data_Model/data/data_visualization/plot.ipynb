# %%
csv_path = "../../../project_datasets/tremor/Tremor_dataset/Preprocessed/file_list.csv"

# %%
from plots import plot_age_histogram_and_find_best_split

ans = plot_age_histogram_and_find_best_split(csv_path)
ans
# Out:
# {'best_k': 3,
#  'boundaries': [58.620843499477175, 71.37997532894738],
#  'silhouette_scores': {3: 0.5669320654927623, 4: 0.5597502078379822}}

# %%
from plots import plot_height_weight_and_find_best_classes

ans = plot_height_weight_and_find_best_classes(csv_path)
ans
# Out:
# {'best_k': 3,
#  'centers': array([[166.61676647,  64.01197605],
#         [178.24390244,  84.50243902],
#         [179.90625   , 107.69791667]]),
#  'silhouette_scores': {3: 0.4190818668757923, 4: 0.35129495236711744}}

# %%
import pandas as pd

df = pd.read_csv(csv_path)

height = df["height"]

sorted_hieghts = min(height.unique())


sorted_hieghts
# Out:
# 55

# %%
row = df[df["height"] == 55]

row
