# %%
csv_path = "../../../project_datasets/tremor/Tremor_dataset/Preprocessed/file_list.csv"

# %%
from csv_prep import create_filtered_classified_csv


_ = create_filtered_classified_csv(csv_path)

# %%
from csv_prep import add_questionnaire_to_csv

_ = add_questionnaire_to_csv("output.csv",
                            "../../../project_datasets/tremor/Tremor_dataset/questionnaire/")
# Out:
# Total subjects loaded from JSON: 469
#
# Total rows in CSV: 355
#
# Matched 355 subjects between CSV and JSON
#
# Saved output to: output.csv
