# %%
from generate_data import train_TVAE

csv_dir = "../../../project_datasets/metadata/real_metadata.csv"
output_dir = "../../../project_datasets/metadata/"

_, _, _ = train_TVAE(csv_dir,
                    output_dir,
                    epochs= 5000)
# Out:
# Training Healthy data synthesizer...
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning:
#
# `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
#
# Loss: -1.652: 100%|██████████| 5000/5000 [00:59<00:00, 83.52it/s]
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning:
#
# `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
# Training PD data synthesizer...
# Loss: 5.858: 100%|██████████| 5000/5000 [01:01<00:00, 80.82it/s]
# Healthy synthesizer saved at ../../../project_datasets/metadata/TVAE_healthy.pkl
# PD synthesizer saved at ../../../project_datasets/metadata/TVAE_pd.pkl

# %%
from generate_data import generate_voice_data

csv_dir = "../../../project_datasets/metadata/real_metadata.csv"
output_dir = "../../../project_datasets/metadata/"

df = generate_voice_data(csv_dir,
                        output_dir,
                        file_name= "generated_metdata",
                        num_generated_samples=100000)
# Out:
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
#
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
# loaded Halthy synthesizer
# loaded PD synthesizer
# loaded Metdata
# Data generated and saved at ../../../project_datasets/metadata/generated_metdata.csv
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 35/35 [00:00<00:00, 117.06it/s]|
# Column Shapes Score: 91.7%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 595/595 [00:04<00:00, 132.37it/s]|
# Column Pair Trends Score: 87.45%
#
# Overall Score (Average): 89.58%
#
# Overall Quality Score: 0.8957510848774715
# Detailed Properties:
#              Property     Score
# ...
