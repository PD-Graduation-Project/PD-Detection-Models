# %% [markdown]
# # 1. Load dataloaders
# - [ ] With `CLAHE`
# - [ ] Without `CLAHE`

# %%
from data.dataloader import create_dataloaders

train_dataloader, val_dataloader = create_dataloaders(
    healthy_dir= "../project_datasets/drawing/Healthy/",
    pd_dir= "../project_datasets/drawing/Parkinson/",
    
    img_size=(224, 224),
    batch_size= 8,
)
# Out:
# Train dataset size: 2611
# Validation dataset size: 653
# -----------------------------------
# Train dataloader size: 326
# Validation dataloader size: 82

# %%
train_inception, val_inception = create_dataloaders(
    healthy_dir= "../project_datasets/drawing/Healthy/",
    pd_dir= "../project_datasets/drawing/Parkinson/",
    
    img_size=(299, 299), # minimum input size for inceptionV3 model
    batch_size= 8,
)
# Out:
# Train dataset size: 2611
# Validation dataset size: 653
# -----------------------------------
# Train dataloader size: 326
# Validation dataloader size: 82

# %% [markdown]
# # 2. Load models
#
# - [ ] DenseNet201 (20.0M)
# - [ ] InceptionV3 (27.2M)
# - [ ] ResNet50 (25.6M)
# - [ ] VGG19_bn (143.7M)
# - [ ] ViT_b16 (86.6M)

# %%
from Models import (
    model_densenet201,
    model_inceptionV3,
    model_resnet50,
    model_vgg19_bn,
    model_Vit_b16
)

models = [
    model_densenet201.create_densenet(),
    model_inceptionV3.create_inception(),
    model_resnet50.create_resnet(),
    model_vgg19_bn.create_vgg(),
    model_Vit_b16.create_vit(),
]

model_names = [
    "DenseNet201",
    "InceptionV3",
    "ResNet50",
    "VGG19_bn",
    "ViT_b16"
]

# %% [markdown]
# # 3. Train models

# %%
from training.trainer import train

for model, model_name in zip(models, model_names):
    train(
        model= model,
        train_dataloader= train_inception if model_name=="InceptionV3" else train_dataloader,
        val_dataloader= val_inception if model_name=="InceptionV3" else val_dataloader,
        
        model_name= model_name,
        run_name= model_name,
        
        epochs= 5
    )
# Out:
# Training model:ViT_b16 epoch no.1 / 5
# -----------------------------------
# Training...:   0%|          | 0/326 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 4
#       1 from training.trainer import train
#       3 for model, model_name in zip(models, model_names):
# ----> 4     train(
#       5         model= model,
#       6         train_dataloader= train_dataloader,
#       7         val_dataloader= val_dataloader,
#       8
#       9         model_name= model_name,
#      10         run_name= model_name,
#      11
#      12         epochs= 5
#      13     )
#
# File d:\Codess & Projects\GRAD\Finalized\1_Spiral_Drawing_Models\training\trainer.py:104, in train(model, train_dataloader, val_dataloader, load_pretrained, checkpoint_dir, model_name, run_name, epochs, max_lr)
#     101 print("-"*35)
#     103 # 5. train
# --> 104 train_loss, train_acc = train_one_epoch(
#     105     model,
#     106     train_dataloader,
#     107
#     108     loss_fn,
#     109     optim,
#     110     binary_accuracy,
#     111
#     112     scaler,
#     113     device
#     114 )
#     116 # 6. validate
#     117 val_loss, val_acc= validate(
#     118     model,
#     119     val_dataloader,
#    (...)
#     124     device
#     125 )
#
# File d:\Codess & Projects\GRAD\Finalized\1_Spiral_Drawing_Models\training\training_loop.py:41, in train_one_epoch(model, train_dataloader, loss_fn, optim, acc_fn, scaler, device)
#      38 # 3. enable auto mixed precision (AMP) for efficiency
#      39 with torch.amp.autocast(device_type= device):
#      40     # 4. forward pass
# ---> 41     logits = model(imgs)
#      42     # if it's an Inception model, it may return a tuple
#      43     if isinstance(logits, tuple):
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\Codess & Projects\.venv\lib\site-packages\torchvision\models\vision_transformer.py:291, in VisionTransformer.forward(self, x)
#     289 def forward(self, x: torch.Tensor):
#     290     # Reshape and permute the input tensor
# --> 291     x = self._process_input(x)
#     292     n = x.shape[0]
#     294     # Expand the class token to the full batch
#
# File d:\Codess & Projects\.venv\lib\site-packages\torchvision\models\vision_transformer.py:271, in VisionTransformer._process_input(self, x)
#     269 n, c, h, w = x.shape
#     270 p = self.patch_size
# --> 271 torch._assert(h == self.image_size, f"Wrong image height! Expected {self.image_size} but got {h}!")
#     272 torch._assert(w == self.image_size, f"Wrong image width! Expected {self.image_size} but got {w}!")
#     273 n_h = h // p
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\__init__.py:2185, in _assert(condition, message)
#    2179 if type(condition) is not torch.Tensor and overrides.has_torch_function(
#    2180     (condition,)
#    2181 ):
#    2182     return overrides.handle_torch_function(
#    2183         _assert, (condition,), condition, message
#    2184     )
# -> 2185 assert condition, message
#
# AssertionError: Wrong image height! Expected 224 but got 299!

# %%
# !tensorboard --logdir=runs
# Out:
# ^C
