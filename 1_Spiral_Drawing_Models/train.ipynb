# %% [markdown]
# # 1. Load dataloaders
# - [ ] With `CLAHE`
# - [ ] Without `CLAHE`

# %%
from data.dataloader import create_dataloaders

train_dataloader, val_dataloader = create_dataloaders(
    healthy_dir= "../project_datasets/drawing/Healthy/",
    pd_dir= "../project_datasets/drawing/Parkinson/",
    batch_size= 8,
)
# Out:
# Train dataset size: 2611
# Validation dataset size: 653
# -----------------------------------
# Train dataloader size: 326
# Validation dataloader size: 82

# %% [markdown]
# # 2. Load model
#
# - [ ] DenseNet201 (20.0M)
# - [ ] InceptionV3 (27.2M)
# - [ ] ResNet50 (25.6M)
# - [ ] VGG19_bn (143.7M)
# - [ ] ViT_b16 (86.6M)

# %%
from Models.model_densenet201 import create_densenet

model = create_densenet()

# %% [markdown]
# # 3. Train model

# %%
from training.trainer import train

train(
    model= model,
    train_dataloader= train_dataloader,
    val_dataloader= val_dataloader,
    
    model_name= "DenseNet201",
    run_name= "DenseNet201",
    
    epochs= 5
)
# Out:
# Training epoch no.1 / 5
# -----------------------------------
# Training...:   0%|          | 0/326 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from training.trainer import train
# ----> 3 train(
#       4     model= model,
#       5     train_dataloader= train_dataloader,
#       6     val_dataloader= val_dataloader,
#       7
#       8     model_name= "DenseNet201",
#       9     run_name= "DenseNet201",
#      10
#      11     epochs= 5
#      12 )
#
# File d:\Codess & Projects\GRAD\Finalized\1_Spiral_Drawing_Models\training\trainer.py:104, in train(model, train_dataloader, val_dataloader, load_pretrained, checkpoint_dir, model_name, run_name, epochs, max_lr)
#     101 print("-"*35)
#     103 # 5. train
# --> 104 train_loss, train_acc = train_one_epoch(
#     105     model,
#     106     train_dataloader,
#     107
#     108     loss_fn,
#     109     optim,
#     110     binary_accuracy,
#     111
#     112     scaler,
#     113     device
#     114 )
#     116 # 6. validate
#     117 val_loss, val_acc= validate(
#     118     model,
#     119     val_dataloader,
#    (...)
#     124     device
#     125 )
#
# File d:\Codess & Projects\GRAD\Finalized\1_Spiral_Drawing_Models\training\training_loop.py:44, in train_one_epoch(model, train_dataloader, loss_fn, optim, acc_fn, scaler, device)
#      41     logits = model(imgs)
#      43     # 5. calculate the losses, and the accuracy
# ---> 44     loss = loss_fn(logits, labels)
#      45     acc = acc_fn(logits, labels)
#      48 # 6. zero grad
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\Codess & Projects\GRAD\Finalized\1_Spiral_Drawing_Models\training\losses.py:37, in WeightedBCE.forward(self, pred, label)
#      35 def forward(self, pred, label):
#      36     # 1 calculate element-wise BCE loss
# ---> 37     bce_loss = self.bce (pred, label)
#      39     # 2. create per-sample weights
#      40     weights = ones_like(label)
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\loss.py:850, in BCEWithLogitsLoss.forward(self, input, target)
#     848 def forward(self, input: Tensor, target: Tensor) -> Tensor:
#     849     """Runs the forward pass."""
# --> 850     return F.binary_cross_entropy_with_logits(
#     851         input,
#     852         target,
#     853         self.weight,
#     854         pos_weight=self.pos_weight,
#     855         reduction=self.reduction,
#     856     )
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\functional.py:3589, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3586     reduction_enum = _Reduction.get_enum(reduction)
#    3588 if not (target.size() == input.size()):
# -> 3589     raise ValueError(
#    3590         f"Target size ({target.size()}) must be the same as input size ({input.size()})"
#    3591     )
#    3593 return torch.binary_cross_entropy_with_logits(
#    3594     input, target, weight, pos_weight, reduction_enum
#    3595 )
#
# ValueError: Target size (torch.Size([8])) must be the same as input size (torch.Size([8, 2]))
