# %%
from torchvision.models import densenet201 
from torchinfo import summary

densenet_model = densenet201(weights = "DEFAULT")
summary(densenet_model, 
        input_size=(1, 3, 512, 512), # (batch, C = 3, H, W)
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
        )
# Out:
# Downloading: "https://download.pytorch.org/models/densenet201-c1103571.pth" to C:\Users\User/.cache\torch\hub\checkpoints\densenet201-c1103571.pth
# 100%|██████████| 77.4M/77.4M [00:26<00:00, 3.06MB/s]
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [1, 3, 512, 512]     [1, 1000]            --                   True
# ├─Sequential (features)                       [1, 3, 512, 512]     [1, 1920, 16, 16]    --                   True
# │    └─Conv2d (conv0)                         [1, 3, 512, 512]     [1, 64, 256, 256]    9,408                True
# │    └─BatchNorm2d (norm0)                    [1, 64, 256, 256]    [1, 64, 256, 256]    128                  True
# │    └─ReLU (relu0)                           [1, 64, 256, 256]    [1, 64, 256, 256]    --                   --
# │    └─MaxPool2d (pool0)                      [1, 64, 256, 256]    [1, 64, 128, 128]    --                   --
# │    └─_DenseBlock (denseblock1)              [1, 64, 128, 128]    [1, 256, 128, 128]   --                   True
# │    │    └─_DenseLayer (denselayer1)         [1, 64, 128, 128]    [1, 32, 128, 128]    45,440               True
# │    │    └─_DenseLayer (denselayer2)         [1, 64, 128, 128]    [1, 32, 128, 128]    49,600               True
# │    │    └─_DenseLayer (denselayer3)         [1, 64, 128, 128]    [1, 32, 128, 128]    53,760               True
# │    │    └─_DenseLayer (denselayer4)         [1, 64, 128, 128]    [1, 32, 128, 128]    57,920               True
# │    │    └─_DenseLayer (denselayer5)         [1, 64, 128, 128]    [1, 32, 128, 128]    62,080               True
# │    │    └─_DenseLayer (denselayer6)         [1, 64, 128, 128]    [1, 32, 128, 128]    66,240               True
# │    └─_Transition (transition1)              [1, 256, 128, 128]   [1, 128, 64, 64]     --                   True
# │    │    └─BatchNorm2d (norm)                [1, 256, 128, 128]   [1, 256, 128, 128]   512                  True
# │    │    └─ReLU (relu)                       [1, 256, 128, 128]   [1, 256, 128, 128]   --                   --
# │    │    └─Conv2d (conv)                     [1, 256, 128, 128]   [1, 128, 128, 128]   32,768               True
# │    │    └─AvgPool2d (pool)                  [1, 128, 128, 128]   [1, 128, 64, 64]     --                   --
# │    └─_DenseBlock (denseblock2)              [1, 128, 64, 64]     [1, 512, 64, 64]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [1, 128, 64, 64]     [1, 32, 64, 64]      53,760               True
# │    │    └─_DenseLayer (denselayer2)         [1, 128, 64, 64]     [1, 32, 64, 64]      57,920               True
# │    │    └─_DenseLayer (denselayer3)         [1, 128, 64, 64]     [1, 32, 64, 64]      62,080               True
# │    │    └─_DenseLayer (denselayer4)         [1, 128, 64, 64]     [1, 32, 64, 64]      66,240               True
# │    │    └─_DenseLayer (denselayer5)         [1, 128, 64, 64]     [1, 32, 64, 64]      70,400               True
# │    │    └─_DenseLayer (denselayer6)         [1, 128, 64, 64]     [1, 32, 64, 64]      74,560               True
# │    │    └─_DenseLayer (denselayer7)         [1, 128, 64, 64]     [1, 32, 64, 64]      78,720               True
# │    │    └─_DenseLayer (denselayer8)         [1, 128, 64, 64]     [1, 32, 64, 64]      82,880               True
# │    │    └─_DenseLayer (denselayer9)         [1, 128, 64, 64]     [1, 32, 64, 64]      87,040               True
# │    │    └─_DenseLayer (denselayer10)        [1, 128, 64, 64]     [1, 32, 64, 64]      91,200               True
# │    │    └─_DenseLayer (denselayer11)        [1, 128, 64, 64]     [1, 32, 64, 64]      95,360               True
# │    │    └─_DenseLayer (denselayer12)        [1, 128, 64, 64]     [1, 32, 64, 64]      99,520               True
# │    └─_Transition (transition2)              [1, 512, 64, 64]     [1, 256, 32, 32]     --                   True
# │    │    └─BatchNorm2d (norm)                [1, 512, 64, 64]     [1, 512, 64, 64]     1,024                True
# │    │    └─ReLU (relu)                       [1, 512, 64, 64]     [1, 512, 64, 64]     --                   --
# │    │    └─Conv2d (conv)                     [1, 512, 64, 64]     [1, 256, 64, 64]     131,072              True
# │    │    └─AvgPool2d (pool)                  [1, 256, 64, 64]     [1, 256, 32, 32]     --                   --
# │    └─_DenseBlock (denseblock3)              [1, 256, 32, 32]     [1, 1792, 32, 32]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [1, 256, 32, 32]     [1, 32, 32, 32]      70,400               True
# │    │    └─_DenseLayer (denselayer2)         [1, 256, 32, 32]     [1, 32, 32, 32]      74,560               True
# │    │    └─_DenseLayer (denselayer3)         [1, 256, 32, 32]     [1, 32, 32, 32]      78,720               True
# │    │    └─_DenseLayer (denselayer4)         [1, 256, 32, 32]     [1, 32, 32, 32]      82,880               True
# │    │    └─_DenseLayer (denselayer5)         [1, 256, 32, 32]     [1, 32, 32, 32]      87,040               True
# │    │    └─_DenseLayer (denselayer6)         [1, 256, 32, 32]     [1, 32, 32, 32]      91,200               True
# │    │    └─_DenseLayer (denselayer7)         [1, 256, 32, 32]     [1, 32, 32, 32]      95,360               True
# │    │    └─_DenseLayer (denselayer8)         [1, 256, 32, 32]     [1, 32, 32, 32]      99,520               True
# │    │    └─_DenseLayer (denselayer9)         [1, 256, 32, 32]     [1, 32, 32, 32]      103,680              True
# │    │    └─_DenseLayer (denselayer10)        [1, 256, 32, 32]     [1, 32, 32, 32]      107,840              True
# │    │    └─_DenseLayer (denselayer11)        [1, 256, 32, 32]     [1, 32, 32, 32]      112,000              True
# │    │    └─_DenseLayer (denselayer12)        [1, 256, 32, 32]     [1, 32, 32, 32]      116,160              True
# │    │    └─_DenseLayer (denselayer13)        [1, 256, 32, 32]     [1, 32, 32, 32]      120,320              True
# │    │    └─_DenseLayer (denselayer14)        [1, 256, 32, 32]     [1, 32, 32, 32]      124,480              True
# │    │    └─_DenseLayer (denselayer15)        [1, 256, 32, 32]     [1, 32, 32, 32]      128,640              True
# │    │    └─_DenseLayer (denselayer16)        [1, 256, 32, 32]     [1, 32, 32, 32]      132,800              True
# │    │    └─_DenseLayer (denselayer17)        [1, 256, 32, 32]     [1, 32, 32, 32]      136,960              True
# │    │    └─_DenseLayer (denselayer18)        [1, 256, 32, 32]     [1, 32, 32, 32]      141,120              True
# │    │    └─_DenseLayer (denselayer19)        [1, 256, 32, 32]     [1, 32, 32, 32]      145,280              True
# │    │    └─_DenseLayer (denselayer20)        [1, 256, 32, 32]     [1, 32, 32, 32]      149,440              True
# │    │    └─_DenseLayer (denselayer21)        [1, 256, 32, 32]     [1, 32, 32, 32]      153,600              True
# │    │    └─_DenseLayer (denselayer22)        [1, 256, 32, 32]     [1, 32, 32, 32]      157,760              True
# │    │    └─_DenseLayer (denselayer23)        [1, 256, 32, 32]     [1, 32, 32, 32]      161,920              True
# │    │    └─_DenseLayer (denselayer24)        [1, 256, 32, 32]     [1, 32, 32, 32]      166,080              True
# │    │    └─_DenseLayer (denselayer25)        [1, 256, 32, 32]     [1, 32, 32, 32]      170,240              True
# │    │    └─_DenseLayer (denselayer26)        [1, 256, 32, 32]     [1, 32, 32, 32]      174,400              True
# │    │    └─_DenseLayer (denselayer27)        [1, 256, 32, 32]     [1, 32, 32, 32]      178,560              True
# │    │    └─_DenseLayer (denselayer28)        [1, 256, 32, 32]     [1, 32, 32, 32]      182,720              True
# │    │    └─_DenseLayer (denselayer29)        [1, 256, 32, 32]     [1, 32, 32, 32]      186,880              True
# │    │    └─_DenseLayer (denselayer30)        [1, 256, 32, 32]     [1, 32, 32, 32]      191,040              True
# │    │    └─_DenseLayer (denselayer31)        [1, 256, 32, 32]     [1, 32, 32, 32]      195,200              True
# │    │    └─_DenseLayer (denselayer32)        [1, 256, 32, 32]     [1, 32, 32, 32]      199,360              True
# │    │    └─_DenseLayer (denselayer33)        [1, 256, 32, 32]     [1, 32, 32, 32]      203,520              True
# │    │    └─_DenseLayer (denselayer34)        [1, 256, 32, 32]     [1, 32, 32, 32]      207,680              True
# │    │    └─_DenseLayer (denselayer35)        [1, 256, 32, 32]     [1, 32, 32, 32]      211,840              True
# │    │    └─_DenseLayer (denselayer36)        [1, 256, 32, 32]     [1, 32, 32, 32]      216,000              True
# │    │    └─_DenseLayer (denselayer37)        [1, 256, 32, 32]     [1, 32, 32, 32]      220,160              True
# │    │    └─_DenseLayer (denselayer38)        [1, 256, 32, 32]     [1, 32, 32, 32]      224,320              True
# │    │    └─_DenseLayer (denselayer39)        [1, 256, 32, 32]     [1, 32, 32, 32]      228,480              True
# │    │    └─_DenseLayer (denselayer40)        [1, 256, 32, 32]     [1, 32, 32, 32]      232,640              True
# │    │    └─_DenseLayer (denselayer41)        [1, 256, 32, 32]     [1, 32, 32, 32]      236,800              True
# │    │    └─_DenseLayer (denselayer42)        [1, 256, 32, 32]     [1, 32, 32, 32]      240,960              True
# │    │    └─_DenseLayer (denselayer43)        [1, 256, 32, 32]     [1, 32, 32, 32]      245,120              True
# │    │    └─_DenseLayer (denselayer44)        [1, 256, 32, 32]     [1, 32, 32, 32]      249,280              True
# │    │    └─_DenseLayer (denselayer45)        [1, 256, 32, 32]     [1, 32, 32, 32]      253,440              True
# │    │    └─_DenseLayer (denselayer46)        [1, 256, 32, 32]     [1, 32, 32, 32]      257,600              True
# │    │    └─_DenseLayer (denselayer47)        [1, 256, 32, 32]     [1, 32, 32, 32]      261,760              True
# │    │    └─_DenseLayer (denselayer48)        [1, 256, 32, 32]     [1, 32, 32, 32]      265,920              True
# │    └─_Transition (transition3)              [1, 1792, 32, 32]    [1, 896, 16, 16]     --                   True
# │    │    └─BatchNorm2d (norm)                [1, 1792, 32, 32]    [1, 1792, 32, 32]    3,584                True
# │    │    └─ReLU (relu)                       [1, 1792, 32, 32]    [1, 1792, 32, 32]    --                   --
# │    │    └─Conv2d (conv)                     [1, 1792, 32, 32]    [1, 896, 32, 32]     1,605,632            True
# │    │    └─AvgPool2d (pool)                  [1, 896, 32, 32]     [1, 896, 16, 16]     --                   --
# │    └─_DenseBlock (denseblock4)              [1, 896, 16, 16]     [1, 1920, 16, 16]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [1, 896, 16, 16]     [1, 32, 16, 16]      153,600              True
# │    │    └─_DenseLayer (denselayer2)         [1, 896, 16, 16]     [1, 32, 16, 16]      157,760              True
# │    │    └─_DenseLayer (denselayer3)         [1, 896, 16, 16]     [1, 32, 16, 16]      161,920              True
# │    │    └─_DenseLayer (denselayer4)         [1, 896, 16, 16]     [1, 32, 16, 16]      166,080              True
# │    │    └─_DenseLayer (denselayer5)         [1, 896, 16, 16]     [1, 32, 16, 16]      170,240              True
# │    │    └─_DenseLayer (denselayer6)         [1, 896, 16, 16]     [1, 32, 16, 16]      174,400              True
# │    │    └─_DenseLayer (denselayer7)         [1, 896, 16, 16]     [1, 32, 16, 16]      178,560              True
# │    │    └─_DenseLayer (denselayer8)         [1, 896, 16, 16]     [1, 32, 16, 16]      182,720              True
# │    │    └─_DenseLayer (denselayer9)         [1, 896, 16, 16]     [1, 32, 16, 16]      186,880              True
# │    │    └─_DenseLayer (denselayer10)        [1, 896, 16, 16]     [1, 32, 16, 16]      191,040              True
# │    │    └─_DenseLayer (denselayer11)        [1, 896, 16, 16]     [1, 32, 16, 16]      195,200              True
# │    │    └─_DenseLayer (denselayer12)        [1, 896, 16, 16]     [1, 32, 16, 16]      199,360              True
# │    │    └─_DenseLayer (denselayer13)        [1, 896, 16, 16]     [1, 32, 16, 16]      203,520              True
# │    │    └─_DenseLayer (denselayer14)        [1, 896, 16, 16]     [1, 32, 16, 16]      207,680              True
# │    │    └─_DenseLayer (denselayer15)        [1, 896, 16, 16]     [1, 32, 16, 16]      211,840              True
# │    │    └─_DenseLayer (denselayer16)        [1, 896, 16, 16]     [1, 32, 16, 16]      216,000              True
# │    │    └─_DenseLayer (denselayer17)        [1, 896, 16, 16]     [1, 32, 16, 16]      220,160              True
# │    │    └─_DenseLayer (denselayer18)        [1, 896, 16, 16]     [1, 32, 16, 16]      224,320              True
# │    │    └─_DenseLayer (denselayer19)        [1, 896, 16, 16]     [1, 32, 16, 16]      228,480              True
# │    │    └─_DenseLayer (denselayer20)        [1, 896, 16, 16]     [1, 32, 16, 16]      232,640              True
# │    │    └─_DenseLayer (denselayer21)        [1, 896, 16, 16]     [1, 32, 16, 16]      236,800              True
# │    │    └─_DenseLayer (denselayer22)        [1, 896, 16, 16]     [1, 32, 16, 16]      240,960              True
# │    │    └─_DenseLayer (denselayer23)        [1, 896, 16, 16]     [1, 32, 16, 16]      245,120              True
# │    │    └─_DenseLayer (denselayer24)        [1, 896, 16, 16]     [1, 32, 16, 16]      249,280              True
# │    │    └─_DenseLayer (denselayer25)        [1, 896, 16, 16]     [1, 32, 16, 16]      253,440              True
# │    │    └─_DenseLayer (denselayer26)        [1, 896, 16, 16]     [1, 32, 16, 16]      257,600              True
# │    │    └─_DenseLayer (denselayer27)        [1, 896, 16, 16]     [1, 32, 16, 16]      261,760              True
# │    │    └─_DenseLayer (denselayer28)        [1, 896, 16, 16]     [1, 32, 16, 16]      265,920              True
# │    │    └─_DenseLayer (denselayer29)        [1, 896, 16, 16]     [1, 32, 16, 16]      270,080              True
# │    │    └─_DenseLayer (denselayer30)        [1, 896, 16, 16]     [1, 32, 16, 16]      274,240              True
# │    │    └─_DenseLayer (denselayer31)        [1, 896, 16, 16]     [1, 32, 16, 16]      278,400              True
# │    │    └─_DenseLayer (denselayer32)        [1, 896, 16, 16]     [1, 32, 16, 16]      282,560              True
# │    └─BatchNorm2d (norm5)                    [1, 1920, 16, 16]    [1, 1920, 16, 16]    3,840                True
# ├─Linear (classifier)                         [1, 1920]            [1, 1000]            1,921,000            True
# =============================================================================================================================
# Total params: 20,013,928
# Trainable params: 20,013,928
# Non-trainable params: 0
# Total mult-adds (G): 22.41
# =============================================================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 1360.80
# Params size (MB): 80.06
# Estimated Total Size (MB): 1444.00
# =============================================================================================================================

# %%
densenet_model

# %%
from torch import nn, inference_mode

# These steps must be followed in this exact order
# -------------------------------------------------

# 1. get the pretraind weights of the original conv2d block (input)
old_conv = densenet_model.features[0]

# 2. create the new conv2d input block, change the input to take 1 channel only (grayscale)
new_conv = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

# 3. average the rgb weights across channels to form one grayscale channel
with inference_mode():
    new_conv.weight[:] = old_conv.weight.mean(dim=1, keepdim=True)
    if old_conv.bias is not None:
        new_conv.bias[:] = old_conv.bias
    
# 4. replace the input block
densenet_model.features[0] = new_conv

# 5. freeze model
for param in densenet_model.parameters():
    param.requires_grad = False

# change the output to 2 classes only (healthy, pd)
# this only unfreezes this block
densenet_model.classifier = nn.Linear(in_features=1920, out_features=2, bias=True)

# %%
summary(densenet_model, 
        input_size=(1, 1, 512, 512), # (batch, C = 1, H, W)
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
        )
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [1, 1, 512, 512]     [1, 2]               --                   Partial
# ├─Sequential (features)                       [1, 1, 512, 512]     [1, 1920, 16, 16]    --                   False
# │    └─Conv2d (conv0)                         [1, 1, 512, 512]     [1, 64, 256, 256]    (3,136)              False
# │    └─BatchNorm2d (norm0)                    [1, 64, 256, 256]    [1, 64, 256, 256]    (128)                False
# │    └─ReLU (relu0)                           [1, 64, 256, 256]    [1, 64, 256, 256]    --                   --
# │    └─MaxPool2d (pool0)                      [1, 64, 256, 256]    [1, 64, 128, 128]    --                   --
# │    └─_DenseBlock (denseblock1)              [1, 64, 128, 128]    [1, 256, 128, 128]   --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 64, 128, 128]    [1, 32, 128, 128]    (45,440)             False
# │    │    └─_DenseLayer (denselayer2)         [1, 64, 128, 128]    [1, 32, 128, 128]    (49,600)             False
# │    │    └─_DenseLayer (denselayer3)         [1, 64, 128, 128]    [1, 32, 128, 128]    (53,760)             False
# │    │    └─_DenseLayer (denselayer4)         [1, 64, 128, 128]    [1, 32, 128, 128]    (57,920)             False
# │    │    └─_DenseLayer (denselayer5)         [1, 64, 128, 128]    [1, 32, 128, 128]    (62,080)             False
# │    │    └─_DenseLayer (denselayer6)         [1, 64, 128, 128]    [1, 32, 128, 128]    (66,240)             False
# │    └─_Transition (transition1)              [1, 256, 128, 128]   [1, 128, 64, 64]     --                   False
# │    │    └─BatchNorm2d (norm)                [1, 256, 128, 128]   [1, 256, 128, 128]   (512)                False
# │    │    └─ReLU (relu)                       [1, 256, 128, 128]   [1, 256, 128, 128]   --                   --
# │    │    └─Conv2d (conv)                     [1, 256, 128, 128]   [1, 128, 128, 128]   (32,768)             False
# │    │    └─AvgPool2d (pool)                  [1, 128, 128, 128]   [1, 128, 64, 64]     --                   --
# │    └─_DenseBlock (denseblock2)              [1, 128, 64, 64]     [1, 512, 64, 64]     --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 128, 64, 64]     [1, 32, 64, 64]      (53,760)             False
# │    │    └─_DenseLayer (denselayer2)         [1, 128, 64, 64]     [1, 32, 64, 64]      (57,920)             False
# │    │    └─_DenseLayer (denselayer3)         [1, 128, 64, 64]     [1, 32, 64, 64]      (62,080)             False
# │    │    └─_DenseLayer (denselayer4)         [1, 128, 64, 64]     [1, 32, 64, 64]      (66,240)             False
# │    │    └─_DenseLayer (denselayer5)         [1, 128, 64, 64]     [1, 32, 64, 64]      (70,400)             False
# │    │    └─_DenseLayer (denselayer6)         [1, 128, 64, 64]     [1, 32, 64, 64]      (74,560)             False
# │    │    └─_DenseLayer (denselayer7)         [1, 128, 64, 64]     [1, 32, 64, 64]      (78,720)             False
# │    │    └─_DenseLayer (denselayer8)         [1, 128, 64, 64]     [1, 32, 64, 64]      (82,880)             False
# │    │    └─_DenseLayer (denselayer9)         [1, 128, 64, 64]     [1, 32, 64, 64]      (87,040)             False
# │    │    └─_DenseLayer (denselayer10)        [1, 128, 64, 64]     [1, 32, 64, 64]      (91,200)             False
# │    │    └─_DenseLayer (denselayer11)        [1, 128, 64, 64]     [1, 32, 64, 64]      (95,360)             False
# │    │    └─_DenseLayer (denselayer12)        [1, 128, 64, 64]     [1, 32, 64, 64]      (99,520)             False
# │    └─_Transition (transition2)              [1, 512, 64, 64]     [1, 256, 32, 32]     --                   False
# │    │    └─BatchNorm2d (norm)                [1, 512, 64, 64]     [1, 512, 64, 64]     (1,024)              False
# │    │    └─ReLU (relu)                       [1, 512, 64, 64]     [1, 512, 64, 64]     --                   --
# │    │    └─Conv2d (conv)                     [1, 512, 64, 64]     [1, 256, 64, 64]     (131,072)            False
# │    │    └─AvgPool2d (pool)                  [1, 256, 64, 64]     [1, 256, 32, 32]     --                   --
# │    └─_DenseBlock (denseblock3)              [1, 256, 32, 32]     [1, 1792, 32, 32]    --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 256, 32, 32]     [1, 32, 32, 32]      (70,400)             False
# │    │    └─_DenseLayer (denselayer2)         [1, 256, 32, 32]     [1, 32, 32, 32]      (74,560)             False
# │    │    └─_DenseLayer (denselayer3)         [1, 256, 32, 32]     [1, 32, 32, 32]      (78,720)             False
# │    │    └─_DenseLayer (denselayer4)         [1, 256, 32, 32]     [1, 32, 32, 32]      (82,880)             False
# │    │    └─_DenseLayer (denselayer5)         [1, 256, 32, 32]     [1, 32, 32, 32]      (87,040)             False
# │    │    └─_DenseLayer (denselayer6)         [1, 256, 32, 32]     [1, 32, 32, 32]      (91,200)             False
# │    │    └─_DenseLayer (denselayer7)         [1, 256, 32, 32]     [1, 32, 32, 32]      (95,360)             False
# │    │    └─_DenseLayer (denselayer8)         [1, 256, 32, 32]     [1, 32, 32, 32]      (99,520)             False
# │    │    └─_DenseLayer (denselayer9)         [1, 256, 32, 32]     [1, 32, 32, 32]      (103,680)            False
# │    │    └─_DenseLayer (denselayer10)        [1, 256, 32, 32]     [1, 32, 32, 32]      (107,840)            False
# │    │    └─_DenseLayer (denselayer11)        [1, 256, 32, 32]     [1, 32, 32, 32]      (112,000)            False
# │    │    └─_DenseLayer (denselayer12)        [1, 256, 32, 32]     [1, 32, 32, 32]      (116,160)            False
# │    │    └─_DenseLayer (denselayer13)        [1, 256, 32, 32]     [1, 32, 32, 32]      (120,320)            False
# │    │    └─_DenseLayer (denselayer14)        [1, 256, 32, 32]     [1, 32, 32, 32]      (124,480)            False
# │    │    └─_DenseLayer (denselayer15)        [1, 256, 32, 32]     [1, 32, 32, 32]      (128,640)            False
# │    │    └─_DenseLayer (denselayer16)        [1, 256, 32, 32]     [1, 32, 32, 32]      (132,800)            False
# │    │    └─_DenseLayer (denselayer17)        [1, 256, 32, 32]     [1, 32, 32, 32]      (136,960)            False
# │    │    └─_DenseLayer (denselayer18)        [1, 256, 32, 32]     [1, 32, 32, 32]      (141,120)            False
# │    │    └─_DenseLayer (denselayer19)        [1, 256, 32, 32]     [1, 32, 32, 32]      (145,280)            False
# │    │    └─_DenseLayer (denselayer20)        [1, 256, 32, 32]     [1, 32, 32, 32]      (149,440)            False
# │    │    └─_DenseLayer (denselayer21)        [1, 256, 32, 32]     [1, 32, 32, 32]      (153,600)            False
# │    │    └─_DenseLayer (denselayer22)        [1, 256, 32, 32]     [1, 32, 32, 32]      (157,760)            False
# │    │    └─_DenseLayer (denselayer23)        [1, 256, 32, 32]     [1, 32, 32, 32]      (161,920)            False
# │    │    └─_DenseLayer (denselayer24)        [1, 256, 32, 32]     [1, 32, 32, 32]      (166,080)            False
# │    │    └─_DenseLayer (denselayer25)        [1, 256, 32, 32]     [1, 32, 32, 32]      (170,240)            False
# │    │    └─_DenseLayer (denselayer26)        [1, 256, 32, 32]     [1, 32, 32, 32]      (174,400)            False
# │    │    └─_DenseLayer (denselayer27)        [1, 256, 32, 32]     [1, 32, 32, 32]      (178,560)            False
# │    │    └─_DenseLayer (denselayer28)        [1, 256, 32, 32]     [1, 32, 32, 32]      (182,720)            False
# │    │    └─_DenseLayer (denselayer29)        [1, 256, 32, 32]     [1, 32, 32, 32]      (186,880)            False
# │    │    └─_DenseLayer (denselayer30)        [1, 256, 32, 32]     [1, 32, 32, 32]      (191,040)            False
# │    │    └─_DenseLayer (denselayer31)        [1, 256, 32, 32]     [1, 32, 32, 32]      (195,200)            False
# │    │    └─_DenseLayer (denselayer32)        [1, 256, 32, 32]     [1, 32, 32, 32]      (199,360)            False
# │    │    └─_DenseLayer (denselayer33)        [1, 256, 32, 32]     [1, 32, 32, 32]      (203,520)            False
# │    │    └─_DenseLayer (denselayer34)        [1, 256, 32, 32]     [1, 32, 32, 32]      (207,680)            False
# │    │    └─_DenseLayer (denselayer35)        [1, 256, 32, 32]     [1, 32, 32, 32]      (211,840)            False
# │    │    └─_DenseLayer (denselayer36)        [1, 256, 32, 32]     [1, 32, 32, 32]      (216,000)            False
# │    │    └─_DenseLayer (denselayer37)        [1, 256, 32, 32]     [1, 32, 32, 32]      (220,160)            False
# │    │    └─_DenseLayer (denselayer38)        [1, 256, 32, 32]     [1, 32, 32, 32]      (224,320)            False
# │    │    └─_DenseLayer (denselayer39)        [1, 256, 32, 32]     [1, 32, 32, 32]      (228,480)            False
# │    │    └─_DenseLayer (denselayer40)        [1, 256, 32, 32]     [1, 32, 32, 32]      (232,640)            False
# │    │    └─_DenseLayer (denselayer41)        [1, 256, 32, 32]     [1, 32, 32, 32]      (236,800)            False
# │    │    └─_DenseLayer (denselayer42)        [1, 256, 32, 32]     [1, 32, 32, 32]      (240,960)            False
# │    │    └─_DenseLayer (denselayer43)        [1, 256, 32, 32]     [1, 32, 32, 32]      (245,120)            False
# │    │    └─_DenseLayer (denselayer44)        [1, 256, 32, 32]     [1, 32, 32, 32]      (249,280)            False
# │    │    └─_DenseLayer (denselayer45)        [1, 256, 32, 32]     [1, 32, 32, 32]      (253,440)            False
# │    │    └─_DenseLayer (denselayer46)        [1, 256, 32, 32]     [1, 32, 32, 32]      (257,600)            False
# │    │    └─_DenseLayer (denselayer47)        [1, 256, 32, 32]     [1, 32, 32, 32]      (261,760)            False
# │    │    └─_DenseLayer (denselayer48)        [1, 256, 32, 32]     [1, 32, 32, 32]      (265,920)            False
# │    └─_Transition (transition3)              [1, 1792, 32, 32]    [1, 896, 16, 16]     --                   False
# │    │    └─BatchNorm2d (norm)                [1, 1792, 32, 32]    [1, 1792, 32, 32]    (3,584)              False
# │    │    └─ReLU (relu)                       [1, 1792, 32, 32]    [1, 1792, 32, 32]    --                   --
# │    │    └─Conv2d (conv)                     [1, 1792, 32, 32]    [1, 896, 32, 32]     (1,605,632)          False
# │    │    └─AvgPool2d (pool)                  [1, 896, 32, 32]     [1, 896, 16, 16]     --                   --
# │    └─_DenseBlock (denseblock4)              [1, 896, 16, 16]     [1, 1920, 16, 16]    --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 896, 16, 16]     [1, 32, 16, 16]      (153,600)            False
# │    │    └─_DenseLayer (denselayer2)         [1, 896, 16, 16]     [1, 32, 16, 16]      (157,760)            False
# │    │    └─_DenseLayer (denselayer3)         [1, 896, 16, 16]     [1, 32, 16, 16]      (161,920)            False
# │    │    └─_DenseLayer (denselayer4)         [1, 896, 16, 16]     [1, 32, 16, 16]      (166,080)            False
# │    │    └─_DenseLayer (denselayer5)         [1, 896, 16, 16]     [1, 32, 16, 16]      (170,240)            False
# │    │    └─_DenseLayer (denselayer6)         [1, 896, 16, 16]     [1, 32, 16, 16]      (174,400)            False
# │    │    └─_DenseLayer (denselayer7)         [1, 896, 16, 16]     [1, 32, 16, 16]      (178,560)            False
# │    │    └─_DenseLayer (denselayer8)         [1, 896, 16, 16]     [1, 32, 16, 16]      (182,720)            False
# │    │    └─_DenseLayer (denselayer9)         [1, 896, 16, 16]     [1, 32, 16, 16]      (186,880)            False
# │    │    └─_DenseLayer (denselayer10)        [1, 896, 16, 16]     [1, 32, 16, 16]      (191,040)            False
# │    │    └─_DenseLayer (denselayer11)        [1, 896, 16, 16]     [1, 32, 16, 16]      (195,200)            False
# │    │    └─_DenseLayer (denselayer12)        [1, 896, 16, 16]     [1, 32, 16, 16]      (199,360)            False
# │    │    └─_DenseLayer (denselayer13)        [1, 896, 16, 16]     [1, 32, 16, 16]      (203,520)            False
# │    │    └─_DenseLayer (denselayer14)        [1, 896, 16, 16]     [1, 32, 16, 16]      (207,680)            False
# │    │    └─_DenseLayer (denselayer15)        [1, 896, 16, 16]     [1, 32, 16, 16]      (211,840)            False
# │    │    └─_DenseLayer (denselayer16)        [1, 896, 16, 16]     [1, 32, 16, 16]      (216,000)            False
# │    │    └─_DenseLayer (denselayer17)        [1, 896, 16, 16]     [1, 32, 16, 16]      (220,160)            False
# │    │    └─_DenseLayer (denselayer18)        [1, 896, 16, 16]     [1, 32, 16, 16]      (224,320)            False
# │    │    └─_DenseLayer (denselayer19)        [1, 896, 16, 16]     [1, 32, 16, 16]      (228,480)            False
# │    │    └─_DenseLayer (denselayer20)        [1, 896, 16, 16]     [1, 32, 16, 16]      (232,640)            False
# │    │    └─_DenseLayer (denselayer21)        [1, 896, 16, 16]     [1, 32, 16, 16]      (236,800)            False
# │    │    └─_DenseLayer (denselayer22)        [1, 896, 16, 16]     [1, 32, 16, 16]      (240,960)            False
# │    │    └─_DenseLayer (denselayer23)        [1, 896, 16, 16]     [1, 32, 16, 16]      (245,120)            False
# │    │    └─_DenseLayer (denselayer24)        [1, 896, 16, 16]     [1, 32, 16, 16]      (249,280)            False
# │    │    └─_DenseLayer (denselayer25)        [1, 896, 16, 16]     [1, 32, 16, 16]      (253,440)            False
# │    │    └─_DenseLayer (denselayer26)        [1, 896, 16, 16]     [1, 32, 16, 16]      (257,600)            False
# │    │    └─_DenseLayer (denselayer27)        [1, 896, 16, 16]     [1, 32, 16, 16]      (261,760)            False
# │    │    └─_DenseLayer (denselayer28)        [1, 896, 16, 16]     [1, 32, 16, 16]      (265,920)            False
# │    │    └─_DenseLayer (denselayer29)        [1, 896, 16, 16]     [1, 32, 16, 16]      (270,080)            False
# │    │    └─_DenseLayer (denselayer30)        [1, 896, 16, 16]     [1, 32, 16, 16]      (274,240)            False
# │    │    └─_DenseLayer (denselayer31)        [1, 896, 16, 16]     [1, 32, 16, 16]      (278,400)            False
# │    │    └─_DenseLayer (denselayer32)        [1, 896, 16, 16]     [1, 32, 16, 16]      (282,560)            False
# │    └─BatchNorm2d (norm5)                    [1, 1920, 16, 16]    [1, 1920, 16, 16]    (3,840)              False
# ├─Linear (classifier)                         [1, 1920]            [1, 2]               3,842                True
# =============================================================================================================================
# Total params: 18,090,498
# Trainable params: 3,842
# Non-trainable params: 18,086,656
# Total mult-adds (G): 22.00
# =============================================================================================================================
# Input size (MB): 1.05
# Forward/backward pass size (MB): 1360.79
# Params size (MB): 72.36
# Estimated Total Size (MB): 1434.20
# =============================================================================================================================

# %%
from model_densenet201 import create_densenet
from torchinfo import summary

model = create_densenet()
summary(model, 
        input_size=(1, 1, 512, 512), # (batch, C = 1, H, W)
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
        )
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [1, 1, 512, 512]     [1, 2]               --                   Partial
# ├─Sequential (features)                       [1, 1, 512, 512]     [1, 1920, 16, 16]    --                   False
# │    └─Conv2d (conv0)                         [1, 1, 512, 512]     [1, 64, 256, 256]    (3,136)              False
# │    └─BatchNorm2d (norm0)                    [1, 64, 256, 256]    [1, 64, 256, 256]    (128)                False
# │    └─ReLU (relu0)                           [1, 64, 256, 256]    [1, 64, 256, 256]    --                   --
# │    └─MaxPool2d (pool0)                      [1, 64, 256, 256]    [1, 64, 128, 128]    --                   --
# │    └─_DenseBlock (denseblock1)              [1, 64, 128, 128]    [1, 256, 128, 128]   --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 64, 128, 128]    [1, 32, 128, 128]    (45,440)             False
# │    │    └─_DenseLayer (denselayer2)         [1, 64, 128, 128]    [1, 32, 128, 128]    (49,600)             False
# │    │    └─_DenseLayer (denselayer3)         [1, 64, 128, 128]    [1, 32, 128, 128]    (53,760)             False
# │    │    └─_DenseLayer (denselayer4)         [1, 64, 128, 128]    [1, 32, 128, 128]    (57,920)             False
# │    │    └─_DenseLayer (denselayer5)         [1, 64, 128, 128]    [1, 32, 128, 128]    (62,080)             False
# │    │    └─_DenseLayer (denselayer6)         [1, 64, 128, 128]    [1, 32, 128, 128]    (66,240)             False
# │    └─_Transition (transition1)              [1, 256, 128, 128]   [1, 128, 64, 64]     --                   False
# │    │    └─BatchNorm2d (norm)                [1, 256, 128, 128]   [1, 256, 128, 128]   (512)                False
# │    │    └─ReLU (relu)                       [1, 256, 128, 128]   [1, 256, 128, 128]   --                   --
# │    │    └─Conv2d (conv)                     [1, 256, 128, 128]   [1, 128, 128, 128]   (32,768)             False
# │    │    └─AvgPool2d (pool)                  [1, 128, 128, 128]   [1, 128, 64, 64]     --                   --
# │    └─_DenseBlock (denseblock2)              [1, 128, 64, 64]     [1, 512, 64, 64]     --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 128, 64, 64]     [1, 32, 64, 64]      (53,760)             False
# │    │    └─_DenseLayer (denselayer2)         [1, 128, 64, 64]     [1, 32, 64, 64]      (57,920)             False
# │    │    └─_DenseLayer (denselayer3)         [1, 128, 64, 64]     [1, 32, 64, 64]      (62,080)             False
# │    │    └─_DenseLayer (denselayer4)         [1, 128, 64, 64]     [1, 32, 64, 64]      (66,240)             False
# │    │    └─_DenseLayer (denselayer5)         [1, 128, 64, 64]     [1, 32, 64, 64]      (70,400)             False
# │    │    └─_DenseLayer (denselayer6)         [1, 128, 64, 64]     [1, 32, 64, 64]      (74,560)             False
# │    │    └─_DenseLayer (denselayer7)         [1, 128, 64, 64]     [1, 32, 64, 64]      (78,720)             False
# │    │    └─_DenseLayer (denselayer8)         [1, 128, 64, 64]     [1, 32, 64, 64]      (82,880)             False
# │    │    └─_DenseLayer (denselayer9)         [1, 128, 64, 64]     [1, 32, 64, 64]      (87,040)             False
# │    │    └─_DenseLayer (denselayer10)        [1, 128, 64, 64]     [1, 32, 64, 64]      (91,200)             False
# │    │    └─_DenseLayer (denselayer11)        [1, 128, 64, 64]     [1, 32, 64, 64]      (95,360)             False
# │    │    └─_DenseLayer (denselayer12)        [1, 128, 64, 64]     [1, 32, 64, 64]      (99,520)             False
# │    └─_Transition (transition2)              [1, 512, 64, 64]     [1, 256, 32, 32]     --                   False
# │    │    └─BatchNorm2d (norm)                [1, 512, 64, 64]     [1, 512, 64, 64]     (1,024)              False
# │    │    └─ReLU (relu)                       [1, 512, 64, 64]     [1, 512, 64, 64]     --                   --
# │    │    └─Conv2d (conv)                     [1, 512, 64, 64]     [1, 256, 64, 64]     (131,072)            False
# │    │    └─AvgPool2d (pool)                  [1, 256, 64, 64]     [1, 256, 32, 32]     --                   --
# │    └─_DenseBlock (denseblock3)              [1, 256, 32, 32]     [1, 1792, 32, 32]    --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 256, 32, 32]     [1, 32, 32, 32]      (70,400)             False
# │    │    └─_DenseLayer (denselayer2)         [1, 256, 32, 32]     [1, 32, 32, 32]      (74,560)             False
# │    │    └─_DenseLayer (denselayer3)         [1, 256, 32, 32]     [1, 32, 32, 32]      (78,720)             False
# │    │    └─_DenseLayer (denselayer4)         [1, 256, 32, 32]     [1, 32, 32, 32]      (82,880)             False
# │    │    └─_DenseLayer (denselayer5)         [1, 256, 32, 32]     [1, 32, 32, 32]      (87,040)             False
# │    │    └─_DenseLayer (denselayer6)         [1, 256, 32, 32]     [1, 32, 32, 32]      (91,200)             False
# │    │    └─_DenseLayer (denselayer7)         [1, 256, 32, 32]     [1, 32, 32, 32]      (95,360)             False
# │    │    └─_DenseLayer (denselayer8)         [1, 256, 32, 32]     [1, 32, 32, 32]      (99,520)             False
# │    │    └─_DenseLayer (denselayer9)         [1, 256, 32, 32]     [1, 32, 32, 32]      (103,680)            False
# │    │    └─_DenseLayer (denselayer10)        [1, 256, 32, 32]     [1, 32, 32, 32]      (107,840)            False
# │    │    └─_DenseLayer (denselayer11)        [1, 256, 32, 32]     [1, 32, 32, 32]      (112,000)            False
# │    │    └─_DenseLayer (denselayer12)        [1, 256, 32, 32]     [1, 32, 32, 32]      (116,160)            False
# │    │    └─_DenseLayer (denselayer13)        [1, 256, 32, 32]     [1, 32, 32, 32]      (120,320)            False
# │    │    └─_DenseLayer (denselayer14)        [1, 256, 32, 32]     [1, 32, 32, 32]      (124,480)            False
# │    │    └─_DenseLayer (denselayer15)        [1, 256, 32, 32]     [1, 32, 32, 32]      (128,640)            False
# │    │    └─_DenseLayer (denselayer16)        [1, 256, 32, 32]     [1, 32, 32, 32]      (132,800)            False
# │    │    └─_DenseLayer (denselayer17)        [1, 256, 32, 32]     [1, 32, 32, 32]      (136,960)            False
# │    │    └─_DenseLayer (denselayer18)        [1, 256, 32, 32]     [1, 32, 32, 32]      (141,120)            False
# │    │    └─_DenseLayer (denselayer19)        [1, 256, 32, 32]     [1, 32, 32, 32]      (145,280)            False
# │    │    └─_DenseLayer (denselayer20)        [1, 256, 32, 32]     [1, 32, 32, 32]      (149,440)            False
# │    │    └─_DenseLayer (denselayer21)        [1, 256, 32, 32]     [1, 32, 32, 32]      (153,600)            False
# │    │    └─_DenseLayer (denselayer22)        [1, 256, 32, 32]     [1, 32, 32, 32]      (157,760)            False
# │    │    └─_DenseLayer (denselayer23)        [1, 256, 32, 32]     [1, 32, 32, 32]      (161,920)            False
# │    │    └─_DenseLayer (denselayer24)        [1, 256, 32, 32]     [1, 32, 32, 32]      (166,080)            False
# │    │    └─_DenseLayer (denselayer25)        [1, 256, 32, 32]     [1, 32, 32, 32]      (170,240)            False
# │    │    └─_DenseLayer (denselayer26)        [1, 256, 32, 32]     [1, 32, 32, 32]      (174,400)            False
# │    │    └─_DenseLayer (denselayer27)        [1, 256, 32, 32]     [1, 32, 32, 32]      (178,560)            False
# │    │    └─_DenseLayer (denselayer28)        [1, 256, 32, 32]     [1, 32, 32, 32]      (182,720)            False
# │    │    └─_DenseLayer (denselayer29)        [1, 256, 32, 32]     [1, 32, 32, 32]      (186,880)            False
# │    │    └─_DenseLayer (denselayer30)        [1, 256, 32, 32]     [1, 32, 32, 32]      (191,040)            False
# │    │    └─_DenseLayer (denselayer31)        [1, 256, 32, 32]     [1, 32, 32, 32]      (195,200)            False
# │    │    └─_DenseLayer (denselayer32)        [1, 256, 32, 32]     [1, 32, 32, 32]      (199,360)            False
# │    │    └─_DenseLayer (denselayer33)        [1, 256, 32, 32]     [1, 32, 32, 32]      (203,520)            False
# │    │    └─_DenseLayer (denselayer34)        [1, 256, 32, 32]     [1, 32, 32, 32]      (207,680)            False
# │    │    └─_DenseLayer (denselayer35)        [1, 256, 32, 32]     [1, 32, 32, 32]      (211,840)            False
# │    │    └─_DenseLayer (denselayer36)        [1, 256, 32, 32]     [1, 32, 32, 32]      (216,000)            False
# │    │    └─_DenseLayer (denselayer37)        [1, 256, 32, 32]     [1, 32, 32, 32]      (220,160)            False
# │    │    └─_DenseLayer (denselayer38)        [1, 256, 32, 32]     [1, 32, 32, 32]      (224,320)            False
# │    │    └─_DenseLayer (denselayer39)        [1, 256, 32, 32]     [1, 32, 32, 32]      (228,480)            False
# │    │    └─_DenseLayer (denselayer40)        [1, 256, 32, 32]     [1, 32, 32, 32]      (232,640)            False
# │    │    └─_DenseLayer (denselayer41)        [1, 256, 32, 32]     [1, 32, 32, 32]      (236,800)            False
# │    │    └─_DenseLayer (denselayer42)        [1, 256, 32, 32]     [1, 32, 32, 32]      (240,960)            False
# │    │    └─_DenseLayer (denselayer43)        [1, 256, 32, 32]     [1, 32, 32, 32]      (245,120)            False
# │    │    └─_DenseLayer (denselayer44)        [1, 256, 32, 32]     [1, 32, 32, 32]      (249,280)            False
# │    │    └─_DenseLayer (denselayer45)        [1, 256, 32, 32]     [1, 32, 32, 32]      (253,440)            False
# │    │    └─_DenseLayer (denselayer46)        [1, 256, 32, 32]     [1, 32, 32, 32]      (257,600)            False
# │    │    └─_DenseLayer (denselayer47)        [1, 256, 32, 32]     [1, 32, 32, 32]      (261,760)            False
# │    │    └─_DenseLayer (denselayer48)        [1, 256, 32, 32]     [1, 32, 32, 32]      (265,920)            False
# │    └─_Transition (transition3)              [1, 1792, 32, 32]    [1, 896, 16, 16]     --                   False
# │    │    └─BatchNorm2d (norm)                [1, 1792, 32, 32]    [1, 1792, 32, 32]    (3,584)              False
# │    │    └─ReLU (relu)                       [1, 1792, 32, 32]    [1, 1792, 32, 32]    --                   --
# │    │    └─Conv2d (conv)                     [1, 1792, 32, 32]    [1, 896, 32, 32]     (1,605,632)          False
# │    │    └─AvgPool2d (pool)                  [1, 896, 32, 32]     [1, 896, 16, 16]     --                   --
# │    └─_DenseBlock (denseblock4)              [1, 896, 16, 16]     [1, 1920, 16, 16]    --                   False
# │    │    └─_DenseLayer (denselayer1)         [1, 896, 16, 16]     [1, 32, 16, 16]      (153,600)            False
# │    │    └─_DenseLayer (denselayer2)         [1, 896, 16, 16]     [1, 32, 16, 16]      (157,760)            False
# │    │    └─_DenseLayer (denselayer3)         [1, 896, 16, 16]     [1, 32, 16, 16]      (161,920)            False
# │    │    └─_DenseLayer (denselayer4)         [1, 896, 16, 16]     [1, 32, 16, 16]      (166,080)            False
# │    │    └─_DenseLayer (denselayer5)         [1, 896, 16, 16]     [1, 32, 16, 16]      (170,240)            False
# │    │    └─_DenseLayer (denselayer6)         [1, 896, 16, 16]     [1, 32, 16, 16]      (174,400)            False
# │    │    └─_DenseLayer (denselayer7)         [1, 896, 16, 16]     [1, 32, 16, 16]      (178,560)            False
# │    │    └─_DenseLayer (denselayer8)         [1, 896, 16, 16]     [1, 32, 16, 16]      (182,720)            False
# │    │    └─_DenseLayer (denselayer9)         [1, 896, 16, 16]     [1, 32, 16, 16]      (186,880)            False
# │    │    └─_DenseLayer (denselayer10)        [1, 896, 16, 16]     [1, 32, 16, 16]      (191,040)            False
# │    │    └─_DenseLayer (denselayer11)        [1, 896, 16, 16]     [1, 32, 16, 16]      (195,200)            False
# │    │    └─_DenseLayer (denselayer12)        [1, 896, 16, 16]     [1, 32, 16, 16]      (199,360)            False
# │    │    └─_DenseLayer (denselayer13)        [1, 896, 16, 16]     [1, 32, 16, 16]      (203,520)            False
# │    │    └─_DenseLayer (denselayer14)        [1, 896, 16, 16]     [1, 32, 16, 16]      (207,680)            False
# │    │    └─_DenseLayer (denselayer15)        [1, 896, 16, 16]     [1, 32, 16, 16]      (211,840)            False
# │    │    └─_DenseLayer (denselayer16)        [1, 896, 16, 16]     [1, 32, 16, 16]      (216,000)            False
# │    │    └─_DenseLayer (denselayer17)        [1, 896, 16, 16]     [1, 32, 16, 16]      (220,160)            False
# │    │    └─_DenseLayer (denselayer18)        [1, 896, 16, 16]     [1, 32, 16, 16]      (224,320)            False
# │    │    └─_DenseLayer (denselayer19)        [1, 896, 16, 16]     [1, 32, 16, 16]      (228,480)            False
# │    │    └─_DenseLayer (denselayer20)        [1, 896, 16, 16]     [1, 32, 16, 16]      (232,640)            False
# │    │    └─_DenseLayer (denselayer21)        [1, 896, 16, 16]     [1, 32, 16, 16]      (236,800)            False
# │    │    └─_DenseLayer (denselayer22)        [1, 896, 16, 16]     [1, 32, 16, 16]      (240,960)            False
# │    │    └─_DenseLayer (denselayer23)        [1, 896, 16, 16]     [1, 32, 16, 16]      (245,120)            False
# │    │    └─_DenseLayer (denselayer24)        [1, 896, 16, 16]     [1, 32, 16, 16]      (249,280)            False
# │    │    └─_DenseLayer (denselayer25)        [1, 896, 16, 16]     [1, 32, 16, 16]      (253,440)            False
# │    │    └─_DenseLayer (denselayer26)        [1, 896, 16, 16]     [1, 32, 16, 16]      (257,600)            False
# │    │    └─_DenseLayer (denselayer27)        [1, 896, 16, 16]     [1, 32, 16, 16]      (261,760)            False
# │    │    └─_DenseLayer (denselayer28)        [1, 896, 16, 16]     [1, 32, 16, 16]      (265,920)            False
# │    │    └─_DenseLayer (denselayer29)        [1, 896, 16, 16]     [1, 32, 16, 16]      (270,080)            False
# │    │    └─_DenseLayer (denselayer30)        [1, 896, 16, 16]     [1, 32, 16, 16]      (274,240)            False
# │    │    └─_DenseLayer (denselayer31)        [1, 896, 16, 16]     [1, 32, 16, 16]      (278,400)            False
# │    │    └─_DenseLayer (denselayer32)        [1, 896, 16, 16]     [1, 32, 16, 16]      (282,560)            False
# │    └─BatchNorm2d (norm5)                    [1, 1920, 16, 16]    [1, 1920, 16, 16]    (3,840)              False
# ├─Linear (classifier)                         [1, 1920]            [1, 2]               3,842                True
# =============================================================================================================================
# Total params: 18,090,498
# Trainable params: 3,842
# Non-trainable params: 18,086,656
# Total mult-adds (G): 22.00
# =============================================================================================================================
# Input size (MB): 1.05
# Forward/backward pass size (MB): 1360.79
# Params size (MB): 72.36
# Estimated Total Size (MB): 1434.20
# =============================================================================================================================
