# %% [markdown]
# # 1. Load dataloaders (for each movement)

# %%
from data.dataloader import create_tremor_dataloaders

train_loader, val_loader = create_tremor_dataloaders(
    "../project_datasets/tremor",
    batch_size= 32,
    print_details=False,
)

# %% [markdown]
# # 2. Create models (for each movement)

# %%
from Models.model_V1 import TremorNetGRU_V1

model = TremorNetGRU_V1()

# %% [markdown]
# # 3. Train models

# %%
from training.trainer import train

train(
    model=model,
    train_dataloader=train_loader,
    val_dataloader=val_loader,
    
    model_name="TremorNetGRU_V1",
    run_name="TremorNetGRU_V1_run5",
    
    epochs = 10,
)
# Out:
# Training model: TremorNetGRU_V1 epoch 1 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:40<00:00,  6.41it/s, Loss=2.0104, Acc=0.4375, Rec=0.3079, Prec=0.2210, F1=0.2530]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 15.40it/s, Loss=1.8972, Acc=0.4375, Rec=0.4667, Prec=0.3222, F1=0.3205]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 1 / 10 summary
# -----------------------------------
# Train Loss = 2.047 | Acc: 0.510 | Recall: 0.342 | Precision: 0.320 | F1: 0.304
# Val Loss = 2.024 | Acc: 0.361 | Recall: 0.400 | Precision: 0.373 | F1: 0.289
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 2 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:38<00:00,  6.71it/s, Loss=1.9271, Acc=0.5312, Rec=0.4030, Prec=0.4362, F1=0.3989]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 14.42it/s, Loss=2.1753, Acc=0.5625, Rec=0.3778, Prec=0.3889, F1=0.3758]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 2 / 10 summary
# -----------------------------------
# Train Loss = 2.001 | Acc: 0.531 | Recall: 0.366 | Precision: 0.376 | F1: 0.335
# Val Loss = 1.981 | Acc: 0.514 | Recall: 0.401 | Precision: 0.428 | F1: 0.388
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 3 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:39<00:00,  6.45it/s, Loss=1.7750, Acc=0.6875, Rec=0.5557, Prec=0.6366, F1=0.5714]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 13.87it/s, Loss=2.0511, Acc=0.3750, Rec=0.2000, Prec=0.1667, F1=0.1818]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 3 / 10 summary
# -----------------------------------
# Train Loss = 1.979 | Acc: 0.520 | Recall: 0.395 | Precision: 0.403 | F1: 0.369
# Val Loss = 1.953 | Acc: 0.518 | Recall: 0.415 | Precision: 0.438 | F1: 0.381
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 4 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:37<00:00,  6.92it/s, Loss=2.0660, Acc=0.3750, Rec=0.2990, Prec=0.2261, F1=0.2574]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 15.98it/s, Loss=2.3309, Acc=0.4375, Rec=0.2333, Prec=0.1944, F1=0.2121]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 4 / 10 summary
# -----------------------------------
# Train Loss = 1.971 | Acc: 0.516 | Recall: 0.408 | Precision: 0.421 | F1: 0.380
# Val Loss = 1.966 | Acc: 0.523 | Recall: 0.384 | Precision: 0.404 | F1: 0.374
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 5 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:40<00:00,  6.40it/s, Loss=2.0331, Acc=0.4062, Rec=0.3939, Prec=0.4667, F1=0.3771]
# Testing...: 100%|██████████| 65/65 [00:05<00:00, 12.59it/s, Loss=2.1398, Acc=0.4375, Rec=0.3111, Prec=0.2667, F1=0.2833]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 5 / 10 summary
# -----------------------------------
# Train Loss = 1.957 | Acc: 0.520 | Recall: 0.419 | Precision: 0.437 | F1: 0.400
# Val Loss = 1.953 | Acc: 0.469 | Recall: 0.434 | Precision: 0.426 | F1: 0.363
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 6 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:41<00:00,  6.13it/s, Loss=1.8898, Acc=0.5312, Rec=0.4667, Prec=0.4343, F1=0.4008]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 14.54it/s, Loss=2.0250, Acc=0.5000, Rec=0.2667, Prec=0.1905, F1=0.2222]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 6 / 10 summary
# -----------------------------------
# Train Loss = 1.952 | Acc: 0.518 | Recall: 0.432 | Precision: 0.435 | F1: 0.402
# Val Loss = 1.950 | Acc: 0.515 | Recall: 0.409 | Precision: 0.411 | F1: 0.384
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 7 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:38<00:00,  6.71it/s, Loss=1.8588, Acc=0.4375, Rec=0.4023, Prec=0.4032, F1=0.3847]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 13.94it/s, Loss=2.0115, Acc=0.3125, Rec=0.1667, Prec=0.1515, F1=0.1587]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 7 / 10 summary
# -----------------------------------
# Train Loss = 1.936 | Acc: 0.519 | Recall: 0.433 | Precision: 0.442 | F1: 0.407
# Val Loss = 1.921 | Acc: 0.518 | Recall: 0.434 | Precision: 0.450 | F1: 0.420
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 8 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:42<00:00,  6.11it/s, Loss=2.0806, Acc=0.3438, Rec=0.3214, Prec=0.2917, F1=0.2783]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 13.80it/s, Loss=2.0255, Acc=0.4375, Rec=0.2333, Prec=0.1795, F1=0.2029]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 8 / 10 summary
# -----------------------------------
# Train Loss = 1.925 | Acc: 0.524 | Recall: 0.455 | Precision: 0.457 | F1: 0.418
# Val Loss = 1.923 | Acc: 0.507 | Recall: 0.426 | Precision: 0.423 | F1: 0.396
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 9 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:41<00:00,  6.22it/s, Loss=1.9307, Acc=0.5312, Rec=0.4722, Prec=0.4120, F1=0.4000]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 16.04it/s, Loss=2.3618, Acc=0.4375, Rec=0.2333, Prec=0.1944, F1=0.2121]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 9 / 10 summary
# -----------------------------------
# Train Loss = 1.920 | Acc: 0.517 | Recall: 0.459 | Precision: 0.449 | F1: 0.420
# Val Loss = 1.940 | Acc: 0.496 | Recall: 0.430 | Precision: 0.428 | F1: 0.417
# ===================================
#
# Training model: TremorNetGRU_V1 epoch 10 / 10
# -----------------------------------
# Training...: 100%|██████████| 257/257 [00:37<00:00,  6.81it/s, Loss=1.8915, Acc=0.6250, Rec=0.5643, Prec=0.5093, F1=0.5071]
# Testing...: 100%|██████████| 65/65 [00:04<00:00, 14.07it/s, Loss=2.1606, Acc=0.3750, Rec=0.2000, Prec=0.1667, F1=0.1818]
# Model: TremorNetGRU_V1 saved.
#
# Epoch 10 / 10 summary
# -----------------------------------
# Train Loss = 1.911 | Acc: 0.525 | Recall: 0.473 | Precision: 0.465 | F1: 0.434
# Val Loss = 1.935 | Acc: 0.513 | Recall: 0.411 | Precision: 0.410 | F1: 0.380
# ===================================

# %%
# !tensorboard --logdir=runs
