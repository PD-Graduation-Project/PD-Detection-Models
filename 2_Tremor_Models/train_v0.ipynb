# %% [markdown]
# # 1. Load dataloaders (for each movement)

# %%
from data.dataloader import create_tremor_dataloaders

all_dataloaders = create_tremor_dataloaders(
    "../project_datasets/tremor/",
    batch_size= 32,
    include_other= False,
    print_details=False,
    per_movement=True
)

# %% [markdown]
# # 2. Create models (for each movement)

# %%
from Models.model_V6_5 import TremorNetGRU_V6_5

models = {}

# Create a model per movement
for movement_name in all_dataloaders.keys():
    model_name = f"{movement_name}_model"
    models[model_name] = TremorNetGRU_V6_5()

print(f"Created {len(models)} models:")
for name in models.keys():
    print(f" - {name}")
# Out:
# Created 11 models:
#  - CrossArms_model
#  - DrinkGlas_model
#  - Entrainment_model
#  - HoldWeight_model
#  - LiftHold_model
#  - PointFinger_model
#  - Relaxed_model
#  - RelaxedTask_model
#  - StretchHold_model
#  - TouchIndex_model
#  - TouchNose_model

# %% [markdown]
# # 3. Train models

# %%
from training.trainer import train

# Train each model on its respective movement
for model_name, model in models.items():
    # Extract movement name by removing "_model"
    movement_name = model_name.replace("_model", "")
    
    # Get the corresponding dataloaders
    train_loader = all_dataloaders[movement_name]["train"]
    test_loader  = all_dataloaders[movement_name]["val"]
    
    # Set dynamic run and save names
    run_name = model_name
    save_name = f"{model_name}.pth"
    
    print(f"\n[INFO] Training {model_name} ...")
    
    train(
        model=model,
        train_dataloader=train_loader,
        val_dataloader=test_loader,
        
        model_name=save_name,
        run_name=run_name,
        
        epochs = 20,
        per_movement = True
    )
# Out:
# [INFO] Training CrossArms_model ...
# Training model: CrossArms_model.pth epoch 1 / 20
# -----------------------------------
# Training...:   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 18
#      14 save_name = f"{model_name}.pth"
#      16 print(f"\n[INFO] Training {model_name} ...")
# ---> 18 train(
#      19     model=model,
#      20     train_dataloader=train_loader,
#      21     val_dataloader=test_loader,
#      22
#      23     model_name=save_name,
#      24     run_name=run_name,
#      25
#      26     epochs = 20,
#      27     per_movement = True
#      28 )
#
# File d:\Codess & Projects\GRAD\Finalized\2_Tremor_Models\training\trainer.py:111, in train(model, train_dataloader, val_dataloader, load_pretrained, checkpoint_dir, model_name, run_name, Tboard, epochs, max_lr, per_movement)
#     108 print("-" * 35)
#     110 # 5. train
# --> 111 train_loss, train_metrics = train_one_epoch(
#     112     model,
#     113     train_dataloader,
#     114     loss_fn,
#     115     binary_metrics,
#     116     optim,
#     117     scaler,
#     118     device,
#     119     per_movement
#     120 )
#     122 # 6. validate
#     123 val_loss, val_metrics = validate(
#     124     model,
#     125     val_dataloader,
#    (...)
#     129     per_movement
#     130 )
#
# File d:\Codess & Projects\GRAD\Finalized\2_Tremor_Models\training\training_loop.py:50, in train_one_epoch(model, train_dataloader, loss_fn, metric_fn, optim, scaler, device, per_movement)
#      48     logits = model(signals, handedness, movements)
#      49 else:
# ---> 50     logits = model(signals, handedness)
#      52 # 5. calculate the losses and metrics
#      53 loss = loss_fn(logits, labels)
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\Codess & Projects\.venv\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\Codess & Projects\GRAD\Finalized\2_Tremor_Models\Models\model_V6_5.py:248, in TremorNetGRU_V6_5.forward(self, x, handedness)
#     245 handed_embed = F.normalize(handed_embed, dim=-1)
#     247 # 2. Encode both wrists
# --> 248 left_feats = self._encode_wrist(x[:, 0], handed_embed)  # [B, hidden_size*6]
#     249 right_feats = self._encode_wrist(x[:, 1], handed_embed)  # [B, hidden_size*6]
#     251 # 3. Cross-wrist attention for interaction modeling
#
# File d:\Codess & Projects\GRAD\Finalized\2_Tremor_Models\Models\model_V6_5.py:204, in TremorNetGRU_V6_5._encode_wrist(self, x, handed_embed)
#     202 seq_len = fused_features.size(1)
#     203 pos_enc = self.pos_encoding[:, :seq_len, :].expand(B, -1, -1)
# --> 204 fused_features = fused_features + pos_enc
#     206 # 4. GRU processing
#     207 gru_out, _ = self.gru(fused_features)
#
# RuntimeError: The size of tensor a (288) must match the size of tensor b (256) at non-singleton dimension 2

# %%
# !tensorboard --logdir=runs
# Out:
# ^C
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
