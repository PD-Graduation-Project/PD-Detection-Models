# %%
from create_dataset import create_clean_dataset

create_clean_dataset()
# Out:
# Loading labels...
# Collecting movement files...
# Processing: 100%|██████████| 5159/5159 [01:50<00:00, 46.72it/s]
# Creating CSV...
#
# ============================================================
# Dataset creation complete!
# CSV saved: C:\Users\YOUSSEF\Desktop\Codess & Projects\GRAD\Final_Project\project_datasets\tremor\tremor_features.csv
# Total segments: 6035
# Skipped (others): 1254
# Movement mapping:
#   0: CrossArms
#   1: DrinkGlas
#   2: Entrainment
#   3: HoldWeight
#   4: LiftHold
#   5: PointFinger
#   6: Relaxed
#   7: RelaxedTask
#   8: StretchHold
#   9: TouchIndex
#   10: TouchNose
# ============================================================
#       movement  handedness  label  segment_idx      lh_1      lh_2  \
# 0            0           1      0            0 -0.232317 -0.415984
# 1            1           1      0            0  0.288270 -0.260040
# 2            2           1      0            0 -0.678346 -0.297515
# 3            2           1      0            1  0.030346 -0.830114
# 4            2           1      0            2  0.097351 -0.218027
# ...        ...         ...    ...          ...       ...       ...
# 6030         7           1      1            1  0.138193 -0.185041
# 6031         7           1      1            2  0.286025 -0.042834
# 6032         8           1      1            0  1.416475  0.238216
# 6033         9           1      1            0 -0.209505  0.040721
# 6034        10           1      1            0  0.022755  0.408127
#
#             lh_3  lh_4      lh_5      lh_6  ...     rh_18     rh_19     rh_20  \
# 0     136.546509  61.0  0.744981  0.000391  ...  1.532283  0.708333  0.729167
# 1      17.508949   5.0  0.085817  0.241459  ...  1.486136  0.166667  0.854167
# 2       7.027008  12.0  0.378486  0.012661  ...  1.590101  0.145833  0.854167
# 3       5.824911  13.0  0.411717  0.003878  ...  1.610114  0.250000  0.854167
# 4       5.944962  13.0  0.378505  0.003270  ...  1.642507  0.208333  0.875000
# ...          ...   ...       ...       ...  ...       ...       ...       ...
# 6030    1.894842   5.0  0.056373  0.182995  ...  1.971875  0.125000  0.875000
# 6031    3.181347   4.0  0.066922  0.029965  ...  1.963621  0.125000  0.166667
# 6032    1.759355   8.0  0.007762 -0.749196  ...  1.971503  0.875000  0.875000
# 6033   25.104523  72.0  0.706732 -0.002264  ...  1.510446  0.729167  0.666667
# 6034    3.537890  18.0  0.214673  0.008456  ...  1.732401  0.270833  0.604167
#
#          rh_21     rh_22     rh_23     rh_24     rh_25     rh_26  rh_27
# 0     0.006136  0.124998  0.181780  0.290902  0.010997  0.003038    0.0
# 1     0.018408  0.260250  0.247546  0.288140  0.075205  0.005868    0.0
# 2     0.196350  0.553172  0.052668  0.032110  0.378783  0.015721    0.0
# 3     0.251573  0.541564  0.051225  0.024524  0.522353  0.024911    4.0
# 4     0.245437  0.558348  0.039553  0.019133  0.406780  0.017469    0.0
# ...        ...       ...       ...       ...       ...       ...    ...
# 6030  0.233165  0.808626  0.005070  0.003026  0.115836  0.011780    0.0
# 6031  0.429515  0.860581  0.004945  0.002503  0.150268  0.011581    0.0
# 6032  0.589049  1.009296  0.009598  0.008363  0.191953  0.002602    0.0
# 6033  0.049087  0.430144  0.282927  0.153365  0.106696  0.010149    0.5
# 6034  0.251573  0.730468  0.357084  0.137615  0.356946  0.017078    0.5
#
# [6035 rows x 58 columns]

# %%
import numpy as np
from pathlib import Path

# Path to one of your saved .npz files
npz_path = Path("../../../project_datasets/tremor/movements/CrossArms/Healthy/45_seg000.npz")

# Load the .npz file
data = np.load(npz_path, allow_pickle=True)

# Print keys to see what’s inside
print("Keys in file:", list(data.keys()))

# Extract contents
features = data["features"]        
label = data["label"].item()
wrist = data["handedness"].item()
subject_id = data["subject_id"].item()

# Inspect structure
print("\n--- File Info ---")
print(f"Subject ID: {subject_id}")
print(f"Label: {label} (0=Healthy, 1=Parkinson, 2=Other)")
print(f"Handedness (wrist): {wrist} (0=Left-handed, 1=Right-handed)")


print("\n--- Signal Shapes ---")
print(f"features shape:  {features.shape}")
# print(f"features: {features}")

# %% [markdown]
# ```
# Creating CSV with 6035 rows...
# ============================================================
# CSV saved: tremor_features.csv
# Total rows: 6035
# Total features: 312
#
# Class distribution:
# label
# 1    4692
# 0    1343
# Name: count, dtype: int64
#
# Movement mapping:
#   0: CrossArms
#   1: DrinkGlas
#   2: Entrainment
#   3: HoldWeight
#   4: LiftHold
#   5: PointFinger
#   6: Relaxed
#   7: RelaxedTask
#   8: StretchHold
#   9: TouchIndex
#   10: TouchNose
# ```
