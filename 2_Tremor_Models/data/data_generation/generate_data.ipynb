# %%
from generate_data import train_TVAE

output_dir = "../../../project_datasets/tremor/"
csv_dir = "../../../project_datasets/tremor/tremor_features.csv"
_, _, _ = train_TVAE(csv_dir= csv_dir,
                    output_dir= output_dir,)
# Out:
# Training Healthy data synthesizer...
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning:
#
# `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
#
# Loss: -61.788: 100%|██████████| 2000/2000 [04:37<00:00,  7.21it/s]
# Training PD data synthesizer...
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning:
#
# `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
#
# Loss: 2.605: 100%|██████████| 1000/1000 [07:09<00:00,  2.33it/s]
# Healthy synthesizer saved at ../../../project_datasets/tremor/TVAE_healthy.pkl
# PD synthesizer saved at ../../../project_datasets/tremor/TVAE_pd.pkl

# %%
from generate_data import generate_voice_data

output_dir = "../../../project_datasets/tremor/"

df = generate_voice_data(csv_dir= csv_dir,
                        output_dir= output_dir,
                        file_name= "PD_GENERATED_TVAE",
                        num_generated_samples=100000)
# Out:
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
# loaded Halthy synthesizer
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
# loaded PD synthesizer
# loaded Metdata
# Data generated and saved at ../../../project_datasets/tremor/PD_GENERATED_TVAE.csv
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 58/58 [00:01<00:00, 51.68it/s]|
# Column Shapes Score: 93.03%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1653/1653 [00:20<00:00, 81.10it/s]|
# Column Pair Trends Score: 95.43%
#
# Overall Score (Average): 94.23%
#
# Overall Quality Score: 0.9423045724293038
# Detailed Properties:
#              Property     Score
# 0       Column Shapes  0.930272
# 1  Column Pair Trends  0.954337
# -----------------------------------

# %%
from generate_GAN import train_GaussianCopula

output_dir = "../../../project_datasets/tremor/"
csv_dir = "../../../project_datasets/tremor/tremor_features.csv"
_, _, _ = train_GaussianCopula(csv_dir= csv_dir,
                    output_dir= output_dir,
                    )
# Out:
# Training Healthy Gaussian Copula synthesizer...
# Training PD Gaussian Copula synthesizer...
# Healthy synthesizer saved at ../../../project_datasets/tremor/GC_healthy.pkl
# PD synthesizer saved at ../../../project_datasets/tremor/GC_pd.pkl

# %%
from generate_GAN import generate_tremor_data_GC

output_dir = "../../../project_datasets/tremor/"

df = generate_tremor_data_GC (csv_dir= csv_dir,
                        output_dir= output_dir,
                        file_name= "PD_GENERATED_GAN",
                        num_generated_samples=100000)
# Out:
# Loaded Healthy GC synthesizer
# Loaded PD GC synthesizer
# Loaded metadata
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
#
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
# Synthetic data saved at ../../../project_datasets/tremor/PD_GENERATED_GAN.csv
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 58/58 [00:00<00:00, 64.51it/s]|
# Column Shapes Score: 85.94%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1653/1653 [00:23<00:00, 71.73it/s]|
# Column Pair Trends Score: 94.61%
#
# Overall Score (Average): 90.28%
#
#
# Overall Quality Score: 0.9027578178977184
# Detailed Properties:
#              Property     Score
# 0       Column Shapes  0.859439
# 1  Column Pair Trends  0.946076
# ----------------------------------------
