# %%
from dataset import TremorDataset

ds = TremorDataset(
    data_path= "../../project_datasets/tremor/movemnets",
)
# Out:
# Loading data: 100%|██████████| 11/11 [01:01<00:00,  5.59s/it]

# %%
ds.get_class_distribution()
# Out:
# {'Healthy': 869, 'Parkinson': 3036, 'Other': 0}

# %%
ds.list_movements()
# Out:
# {'CrossArms': 0,
#  'DrinkGlas': 1,
#  'Entrainment': 2,
#  'HoldWeight': 3,
#  'LiftHold': 4,
#  'PointFinger': 5,
#  'Relaxed': 6,
#  'RelaxedTask': 7,
#  'StretchHold': 8,
#  'TouchIndex': 9,
#  'TouchNose': 10}
