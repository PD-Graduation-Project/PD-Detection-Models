# %%
from data.dataloader import create_tremor_dataloaders

all_dataloaders = create_tremor_dataloaders(
    "../project_datasets/tremor/",
    batch_size= 32,
    include_other= False,
    print_details=False,
    per_movement=True
)

# %%
from data.plot_data import plot_movement_comparison

plot_movement_comparison(all_dataloaders)
# Out:
# [INFO] Processing movement: CrossArms
# [INFO] Processing movement: DrinkGlas
# [INFO] Processing movement: Entrainment
# [INFO] Processing movement: HoldWeight
# [INFO] Processing movement: LiftHold
# [INFO] Processing movement: PointFinger
# [INFO] Processing movement: Relaxed
# [INFO] Processing movement: RelaxedTask
# [INFO] Processing movement: StretchHold
# [INFO] Processing movement: TouchIndex
# [INFO] Processing movement: TouchNose
#
# [INFO] Saved PDF: movement_comparison.pdf

# %%
from data.plot_data import plot_movement_comparison_by_dominance

plot_movement_comparison_by_dominance(all_dataloaders)
# Out:
# [INFO] Processing movement: CrossArms
# [INFO] Processing movement: DrinkGlas
# [INFO] Processing movement: Entrainment
# [INFO] Processing movement: HoldWeight
# [INFO] Processing movement: LiftHold
# [INFO] Processing movement: PointFinger
# [INFO] Processing movement: Relaxed
# [INFO] Processing movement: RelaxedTask
# [INFO] Processing movement: StretchHold
# [INFO] Processing movement: TouchIndex
# [INFO] Processing movement: TouchNose
#
# [INFO] Saved Dominance comparison PDF to: movement_comparison_dominance.pdf
