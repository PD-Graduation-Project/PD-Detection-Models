# %%
from data.dataloader import create_tremor_dataloaders

train, val = create_tremor_dataloaders(data_path= "../project_datasets/tremor/",
                                    include_other= False,
                                    print_details= True)
# Out:
# Found 11 movements: ['CrossArms', 'DrinkGlas', 'Entrainment', 'HoldWeight', 'LiftHold', 'PointFinger', 'Relaxed', 'RelaxedTask', 'StretchHold', 'TouchIndex', 'TouchNose']
#   Loaded CrossArms: 355 samples
#   Loaded DrinkGlas: 355 samples
#   Loaded Entrainment: 355 samples
#   Loaded HoldWeight: 355 samples
#   Loaded LiftHold: 355 samples
#   Loaded PointFinger: 355 samples
#   Loaded Relaxed: 355 samples
#   Loaded RelaxedTask: 355 samples
#   Loaded StretchHold: 355 samples
#   Loaded TouchIndex: 355 samples
#   Loaded TouchNose: 355 samples
#
# Total samples loaded: 3905
#   Healthy: 869
#   Parkinson: 3036
#
# ============================================================
# Dataset Summary
# ============================================================
# Total samples: 3905
# Train: 3124 | Val: 781
# Movements: 11
#
# Class Distribution:
#   Healthy     :  869 (22.3%)
#   Parkinson   : 3036 (77.7%)
#   Other       :    0 (0.0%)
# ============================================================

# %%
train, val = create_tremor_dataloaders(data_path= "../project_datasets/tremor/",
                                    include_other= True,
                                    print_details= True)
# Out:
# Found 11 movements: ['CrossArms', 'DrinkGlas', 'Entrainment', 'HoldWeight', 'LiftHold', 'PointFinger', 'Relaxed', 'RelaxedTask', 'StretchHold', 'TouchIndex', 'TouchNose']
#   Loaded CrossArms: 469 samples
#   Loaded DrinkGlas: 469 samples
#   Loaded Entrainment: 469 samples
#   Loaded HoldWeight: 469 samples
#   Loaded LiftHold: 469 samples
#   Loaded PointFinger: 469 samples
#   Loaded Relaxed: 469 samples
#   Loaded RelaxedTask: 469 samples
#   Loaded StretchHold: 469 samples
#   Loaded TouchIndex: 469 samples
#   Loaded TouchNose: 469 samples
#
# Total samples loaded: 5159
#   Healthy: 869
#   Parkinson: 3036
#   Other: 1254
#
# ============================================================
# Dataset Summary
# ============================================================
# Total samples: 5159
# Train: 4127 | Val: 1032
# Movements: 11
#
# Class Distribution:
#   Healthy     :  869 (16.8%)
#   Parkinson   : 3036 (58.8%)
#   Other       : 1254 (24.3%)
# ============================================================

# %%
from data.dataloader import create_tremor_dataloaders

movement_dataloaders = create_tremor_dataloaders(data_path= "../project_datasets/tremor/",
                                    include_other= False,
                                    print_details= True,
                                    per_movement=True)
# Out:
# Found 11 movements: ['CrossArms', 'DrinkGlas', 'Entrainment', 'HoldWeight', 'LiftHold', 'PointFinger', 'Relaxed', 'RelaxedTask', 'StretchHold', 'TouchIndex', 'TouchNose']
#   Loaded CrossArms: 355 samples
#   Loaded DrinkGlas: 355 samples
#   Loaded Entrainment: 355 samples
#   Loaded HoldWeight: 355 samples
#   Loaded LiftHold: 355 samples
#   Loaded PointFinger: 355 samples
#   Loaded Relaxed: 355 samples
#   Loaded RelaxedTask: 355 samples
#   Loaded StretchHold: 355 samples
#   Loaded TouchIndex: 355 samples
#   Loaded TouchNose: 355 samples
#
# Total samples loaded: 3905
#   Healthy: 869
#   Parkinson: 3036
# [CrossArms]  Train: 284 | Val: 71
# [DrinkGlas]  Train: 284 | Val: 71
# [Entrainment]  Train: 284 | Val: 71
# [HoldWeight]  Train: 284 | Val: 71
# [LiftHold]  Train: 284 | Val: 71
# [PointFinger]  Train: 284 | Val: 71
# [Relaxed]  Train: 284 | Val: 71
# [RelaxedTask]  Train: 284 | Val: 71
# [StretchHold]  Train: 284 | Val: 71
# [TouchIndex]  Train: 284 | Val: 71
# [TouchNose]  Train: 284 | Val: 71

# %%
batch = next(iter(movement_dataloaders['CrossArms']['train']))

# %%
batch[0].shape
# Out:
# torch.Size([32, 2, 1024, 6])
