# %%
from dataset import TremorDataset

ds = TremorDataset(
    data_path= "../../project_datasets/tremor/movemnets",
)

# %%
from dataloader import create_tremor_dataloaders

train, test = create_tremor_dataloaders(
    data_path= "../../project_datasets/tremor/movemnets",
    print_details = True
)

# %%
ds.get_class_distribution()

# %%
ds.list_movements()

# %%
batch = next(iter(test))
signals, handedness, movement, labels = batch
signals, handedness, movement, labels
