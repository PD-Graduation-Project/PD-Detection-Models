# %%
import torch
from torchinfo import summary
from model_V6_5 import TremorNetGRU_V6_5  # Update path if needed

# 1. Instantiate model
model = TremorNetGRU_V6_5()

# 2. Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# 3. Dummy inputs
# x: [batch, time_steps, channels] = [32, 2, 1024, 6]
# wrist: [batch] = [1]
x = torch.zeros(32, 2, 1024, 6, device=device)
handedness  = torch.zeros(32, dtype=torch.long, device=device)

# 4. Print detailed model summary
summary(
    model=model,
    input_data=(x, handedness ),  # Multi-input tuple
    col_names=[
        "input_size",
        "output_size",
        "num_params",
        "trainable",
    ],
    col_width=20,
    row_settings=["var_names"],  # show variable names
    depth=4                      # controls recursion depth
)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# TremorNetGRU_V6_5 (TremorNetGRU_V6_5)         [32, 2, 1024, 6]     [32, 1]              288,000              True
# ├─Embedding (handedness_embed)                [32]                 [32, 32]             64                   True
# ├─Sequential (handedness_proj)                [32, 32]             [32, 32]             --                   True
# │    └─Linear (0)                             [32, 32]             [32, 64]             2,112                True
# │    └─GELU (1)                               [32, 64]             [32, 64]             --                   --
# │    └─Linear (2)                             [32, 64]             [32, 32]             2,080                True
# │    └─LayerNorm (3)                          [32, 32]             [32, 32]             64                   True
# ├─Sequential (conv1)                          [32, 6, 1024]        [32, 64, 512]        --                   True
# │    └─Conv1d (0)                             [32, 6, 1024]        [32, 64, 512]        2,688                True
# │    └─BatchNorm1d (1)                        [32, 64, 512]        [32, 64, 512]        128                  True
# │    └─GELU (2)                               [32, 64, 512]        [32, 64, 512]        --                   --
# │    └─Dropout (3)                            [32, 64, 512]        [32, 64, 512]        --                   --
# │    └─Conv1d (4)                             [32, 64, 512]        [32, 64, 512]        12,288               True
# │    └─BatchNorm1d (5)                        [32, 64, 512]        [32, 64, 512]        128                  True
# │    └─GELU (6)                               [32, 64, 512]        [32, 64, 512]        --                   --
# │    └─Dropout (7)                            [32, 64, 512]        [32, 64, 512]        --                   --
# ├─Sequential (conv2)                          [32, 64, 512]        [32, 128, 256]       --                   True
# │    └─Conv1d (0)                             [32, 64, 512]        [32, 128, 256]       40,960               True
# │    └─BatchNorm1d (1)                        [32, 128, 256]       [32, 128, 256]       256                  True
# │    └─GELU (2)                               [32, 128, 256]       [32, 128, 256]       --                   --
# │    └─Dropout (3)                            [32, 128, 256]       [32, 128, 256]       --                   --
# │    └─Conv1d (4)                             [32, 128, 256]       [32, 128, 256]       49,152               True
# │    └─BatchNorm1d (5)                        [32, 128, 256]       [32, 128, 256]       256                  True
# │    └─GELU (6)                               [32, 128, 256]       [32, 128, 256]       --                   --
# │    └─Dropout (7)                            [32, 128, 256]       [32, 128, 256]       --                   --
# ├─Sequential (conv3)                          [32, 128, 256]       [32, 256, 256]       --                   True
# │    └─Conv1d (0)                             [32, 128, 256]       [32, 256, 256]       98,304               True
# │    └─BatchNorm1d (1)                        [32, 256, 256]       [32, 256, 256]       512                  True
# │    └─GELU (2)                               [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Dropout (3)                            [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Conv1d (4)                             [32, 256, 256]       [32, 256, 256]       196,608              True
# │    └─BatchNorm1d (5)                        [32, 256, 256]       [32, 256, 256]       512                  True
# │    └─GELU (6)                               [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Dropout (7)                            [32, 256, 256]       [32, 256, 256]       --                   --
# ├─Conv1d (dilated_conv)                       [32, 256, 256]       [32, 256, 256]       196,864              True
# ├─BatchNorm1d (conv_bn)                       [32, 256, 256]       [32, 256, 256]       512                  True
# ├─Sequential (channel_attention)              [32, 256, 256]       [32, 256]            --                   True
# │    └─AdaptiveAvgPool1d (0)                  [32, 256, 256]       [32, 256, 1]         --                   --
# │    └─Flatten (1)                            [32, 256, 1]         [32, 256]            --                   --
# │    └─Linear (2)                             [32, 256]            [32, 16]             4,112                True
# │    └─ReLU (3)                               [32, 16]             [32, 16]             --                   --
# │    └─Linear (4)                             [32, 16]             [32, 256]            4,352                True
# │    └─Sigmoid (5)                            [32, 256]            [32, 256]            --                   --
# ├─GRU (gru)                                   [32, 256, 288]       [32, 256, 256]       617,472              True
# ├─LayerNorm (gru_ln)                          [32, 256, 256]       [32, 256, 256]       512                  True
# ├─MultiheadAttention (multihead_attn)         [32, 256, 256]       [32, 256, 256]       263,168              True
# ├─Sequential (attention_proj)                 [32, 256, 256]       [32, 256, 256]       --                   True
# │    └─Linear (0)                             [32, 256, 256]       [32, 256, 256]       65,792               True
# │    └─LayerNorm (1)                          [32, 256, 256]       [32, 256, 256]       512                  True
# │    └─GELU (2)                               [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Dropout (3)                            [32, 256, 256]       [32, 256, 256]       --                   --
# ├─Sequential (conv1)                          [32, 6, 1024]        [32, 64, 512]        (recursive)          True
# │    └─Conv1d (0)                             [32, 6, 1024]        [32, 64, 512]        (recursive)          True
# │    └─BatchNorm1d (1)                        [32, 64, 512]        [32, 64, 512]        (recursive)          True
# │    └─GELU (2)                               [32, 64, 512]        [32, 64, 512]        --                   --
# │    └─Dropout (3)                            [32, 64, 512]        [32, 64, 512]        --                   --
# │    └─Conv1d (4)                             [32, 64, 512]        [32, 64, 512]        (recursive)          True
# │    └─BatchNorm1d (5)                        [32, 64, 512]        [32, 64, 512]        (recursive)          True
# │    └─GELU (6)                               [32, 64, 512]        [32, 64, 512]        --                   --
# │    └─Dropout (7)                            [32, 64, 512]        [32, 64, 512]        --                   --
# ├─Sequential (conv2)                          [32, 64, 512]        [32, 128, 256]       (recursive)          True
# │    └─Conv1d (0)                             [32, 64, 512]        [32, 128, 256]       (recursive)          True
# │    └─BatchNorm1d (1)                        [32, 128, 256]       [32, 128, 256]       (recursive)          True
# │    └─GELU (2)                               [32, 128, 256]       [32, 128, 256]       --                   --
# │    └─Dropout (3)                            [32, 128, 256]       [32, 128, 256]       --                   --
# │    └─Conv1d (4)                             [32, 128, 256]       [32, 128, 256]       (recursive)          True
# │    └─BatchNorm1d (5)                        [32, 128, 256]       [32, 128, 256]       (recursive)          True
# │    └─GELU (6)                               [32, 128, 256]       [32, 128, 256]       --                   --
# │    └─Dropout (7)                            [32, 128, 256]       [32, 128, 256]       --                   --
# ├─Sequential (conv3)                          [32, 128, 256]       [32, 256, 256]       (recursive)          True
# │    └─Conv1d (0)                             [32, 128, 256]       [32, 256, 256]       (recursive)          True
# │    └─BatchNorm1d (1)                        [32, 256, 256]       [32, 256, 256]       (recursive)          True
# │    └─GELU (2)                               [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Dropout (3)                            [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Conv1d (4)                             [32, 256, 256]       [32, 256, 256]       (recursive)          True
# │    └─BatchNorm1d (5)                        [32, 256, 256]       [32, 256, 256]       (recursive)          True
# │    └─GELU (6)                               [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Dropout (7)                            [32, 256, 256]       [32, 256, 256]       --                   --
# ├─Conv1d (dilated_conv)                       [32, 256, 256]       [32, 256, 256]       (recursive)          True
# ├─BatchNorm1d (conv_bn)                       [32, 256, 256]       [32, 256, 256]       (recursive)          True
# ├─Sequential (channel_attention)              [32, 256, 256]       [32, 256]            (recursive)          True
# │    └─AdaptiveAvgPool1d (0)                  [32, 256, 256]       [32, 256, 1]         --                   --
# │    └─Flatten (1)                            [32, 256, 1]         [32, 256]            --                   --
# │    └─Linear (2)                             [32, 256]            [32, 16]             (recursive)          True
# │    └─ReLU (3)                               [32, 16]             [32, 16]             --                   --
# │    └─Linear (4)                             [32, 16]             [32, 256]            (recursive)          True
# │    └─Sigmoid (5)                            [32, 256]            [32, 256]            --                   --
# ├─GRU (gru)                                   [32, 256, 288]       [32, 256, 256]       (recursive)          True
# ├─LayerNorm (gru_ln)                          [32, 256, 256]       [32, 256, 256]       (recursive)          True
# ├─MultiheadAttention (multihead_attn)         [32, 256, 256]       [32, 256, 256]       (recursive)          True
# ├─Sequential (attention_proj)                 [32, 256, 256]       [32, 256, 256]       (recursive)          True
# │    └─Linear (0)                             [32, 256, 256]       [32, 256, 256]       (recursive)          True
# │    └─LayerNorm (1)                          [32, 256, 256]       [32, 256, 256]       (recursive)          True
# │    └─GELU (2)                               [32, 256, 256]       [32, 256, 256]       --                   --
# │    └─Dropout (3)                            [32, 256, 256]       [32, 256, 256]       --                   --
# ├─MultiheadAttention (cross_attention)        [32, 2, 1280]        [32, 2, 1280]        6,558,720            True
# ├─Sequential (classifier)                     --                   --                   (recursive)          True
# │    └─Linear (0)                             [32, 3872]           [32, 512]            1,982,976            True
# │    └─LayerNorm (1)                          [32, 512]            [32, 512]            1,024                True
# │    └─GELU (2)                               [32, 512]            [32, 512]            --                   --
# │    └─Dropout (3)                            [32, 512]            [32, 512]            --                   --
# ├─Linear (classifier_residual1)               [32, 3872]           [32, 512]            1,982,976            True
# ├─Sequential (classifier)                     --                   --                   (recursive)          True
# │    └─Linear (4)                             [32, 512]            [32, 256]            131,328              True
# │    └─LayerNorm (5)                          [32, 256]            [32, 256]            512                  True
# │    └─GELU (6)                               [32, 256]            [32, 256]            --                   --
# │    └─Dropout (7)                            [32, 256]            [32, 256]            --                   --
# ├─Linear (classifier_residual2)               [32, 512]            [32, 256]            131,328              True
# ├─Sequential (classifier)                     --                   --                   (recursive)          True
# │    └─Linear (8)                             [32, 256]            [32, 128]            32,896               True
# │    └─GELU (9)                               [32, 128]            [32, 128]            --                   --
# │    └─Dropout (10)                           [32, 128]            [32, 128]            --                   --
# │    └─Linear (11)                            [32, 128]            [32, 1]              129                  True
# =============================================================================================================================
# Total params: 12,669,297
# Trainable params: 12,669,297
# Non-trainable params: 0
# Total mult-adds (G): 20.28
# =============================================================================================================================
# Input size (MB): 1.57
# Forward/backward pass size (MB): 470.57
# Params size (MB): 22.24
# Estimated Total Size (MB): 494.38
# =============================================================================================================================
