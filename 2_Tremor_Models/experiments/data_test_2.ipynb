# %%
from data.dataset_creation import create_preprocessed_dataset

create_preprocessed_dataset()
# Out:
# Creating dataset...: 100%|██████████| 10318/10318 [03:10<00:00, 54.16it/s]
# Finished preprocessing. Saved dataset to: D:\Codess & Projects\GRAD\Finalized\project_datasets\tremor

# %%
from data.dataloader import create_tremor_dataloaders

train, val = create_tremor_dataloaders(data_path= "../project_datasets/tremor/",
                                    include_other= False,
                                    print_details= True)
# Out:
# Found 11 movements: ['CrossArms', 'DrinkGlas', 'Entrainment', 'HoldWeight', 'LiftHold', 'PointFinger', 'Relaxed', 'RelaxedTask', 'StretchHold', 'TouchIndex', 'TouchNose']
#   Loaded CrossArms: 710 samples
#   Loaded DrinkGlas: 710 samples
#   Loaded Entrainment: 710 samples
#   Loaded HoldWeight: 710 samples
#   Loaded LiftHold: 710 samples
#   Loaded PointFinger: 710 samples
#   Loaded Relaxed: 710 samples
#   Loaded RelaxedTask: 710 samples
#   Loaded StretchHold: 710 samples
#   Loaded TouchIndex: 710 samples
#   Loaded TouchNose: 710 samples
#
# Total samples loaded: 7810
#   Healthy: 1738
#   Parkinson: 6072
#
# ...
# Dataset Summary
# ...
# Total samples: 7810
# Train: 6248 | Val: 1562
# Movements: 11
#
# Class Distribution:
#   Healthy     : 1738 (22.3%)
#   Parkinson   : 6072 (77.7%)
#   Other       :    0 (0.0%)
# ...

# %%
train, val = create_tremor_dataloaders(data_path= "../project_datasets/tremor/",
                                    include_other= True,
                                    print_details= True)
# Out:
# Found 11 movements: ['CrossArms', 'DrinkGlas', 'Entrainment', 'HoldWeight', 'LiftHold', 'PointFinger', 'Relaxed', 'RelaxedTask', 'StretchHold', 'TouchIndex', 'TouchNose']
#   Loaded CrossArms: 938 samples
#   Loaded DrinkGlas: 938 samples
#   Loaded Entrainment: 938 samples
#   Loaded HoldWeight: 938 samples
#   Loaded LiftHold: 938 samples
#   Loaded PointFinger: 938 samples
#   Loaded Relaxed: 938 samples
#   Loaded RelaxedTask: 938 samples
#   Loaded StretchHold: 938 samples
#   Loaded TouchIndex: 938 samples
#   Loaded TouchNose: 938 samples
#
# Total samples loaded: 10318
#   Healthy: 1738
#   Parkinson: 6072
#   Other: 2508
#
# ...
# Dataset Summary
# ...
# Total samples: 10318
# Train: 8254 | Val: 2064
# Movements: 11
#
# Class Distribution:
#   Healthy     : 1738 (16.8%)
#   Parkinson   : 6072 (58.8%)
#   Other       : 2508 (24.3%)
# ...

# %%
from data.dataloader import create_tremor_dataloaders

movement_dataloaders = create_tremor_dataloaders(data_path= "../project_datasets/tremor/",
                                    include_other= False,
                                    print_details= True,
                                    per_movemnet=True)
# Out:
# Found 11 movements: ['CrossArms', 'DrinkGlas', 'Entrainment', 'HoldWeight', 'LiftHold', 'PointFinger', 'Relaxed', 'RelaxedTask', 'StretchHold', 'TouchIndex', 'TouchNose']
#   Loaded CrossArms: 710 samples
#   Loaded DrinkGlas: 710 samples
#   Loaded Entrainment: 710 samples
#   Loaded HoldWeight: 710 samples
#   Loaded LiftHold: 710 samples
#   Loaded PointFinger: 710 samples
#   Loaded Relaxed: 710 samples
#   Loaded RelaxedTask: 710 samples
#   Loaded StretchHold: 710 samples
#   Loaded TouchIndex: 710 samples
#   Loaded TouchNose: 710 samples
#
# Total samples loaded: 7810
#   Healthy: 1738
#   Parkinson: 6072
# [CrossArms]  Train: 568 | Val: 142
# [DrinkGlas]  Train: 568 | Val: 142
# [Entrainment]  Train: 568 | Val: 142
# [HoldWeight]  Train: 568 | Val: 142
# [LiftHold]  Train: 568 | Val: 142
# [PointFinger]  Train: 568 | Val: 142
# [Relaxed]  Train: 568 | Val: 142
# [RelaxedTask]  Train: 568 | Val: 142
# [StretchHold]  Train: 568 | Val: 142
# [TouchIndex]  Train: 568 | Val: 142
# ...

# %%
movement_dataloaders['CrossArms']
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x2639f099990>,
#  'val': <torch.utils.data.dataloader.DataLoader at 0x2639f0cab30>}
