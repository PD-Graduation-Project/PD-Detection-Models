# %%
from generate_data import train_TVAE

output_dir = "../../../project_datasets/audio/tubular/"
csv_dir = "../../../project_datasets/audio/tubular/parkinsons_real.csv"
_, _, _ = train_TVAE(csv_dir= csv_dir,
                    output_dir= output_dir,
                    epochs= 10000)
# Out:
# Training Healthy data synthesizer...
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning:
#
# `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
#
# Loss: -175.714: 100%|██████████| 10000/10000 [03:30<00:00, 47.57it/s]
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning:
#
# `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
# Training PD data synthesizer...
# Loss: -176.295: 100%|██████████| 10000/10000 [03:29<00:00, 47.78it/s]
# Healthy synthesizer saved at ../../../project_datasets/audio/tubular/TVAE_healthy.pkl
# PD synthesizer saved at ../../../project_datasets/audio/tubular/TVAE_pd.pkl

# %%
from generate_data import generate_voice_data

output_dir = "../../../project_datasets/audio/tubular"

df = generate_voice_data(csv_dir= csv_dir,
                        output_dir= output_dir,
                        file_name= "parkinsons_generated_2",
                        num_generated_samples=100000)
# Out:
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
#
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
# loaded Halthy synthesizer
# loaded PD synthesizer
# loaded Metdata
# Data generated and saved at ../../../project_datasets/audio/tubular\parkinsons_generated_2.csv
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 26/26 [00:00<00:00, 88.13it/s]|
# Column Shapes Score: 88.81%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 325/325 [00:04<00:00, 75.31it/s]|
# Column Pair Trends Score: 93.18%
#
# Overall Score (Average): 91.0%
#
# Overall Quality Score: 0.9099564680282488
# Detailed Properties:
#              Property     Score
# 0       Column Shapes  0.888114
# 1  Column Pair Trends  0.931799
# -----------------------------------
