# %%
from dataloader import create_dataloaders

t, v = create_dataloaders("../../../project_datasets/audio/tubular/parkinsons_real.csv")
# Out:
# ...
# Train dataset size:      156
# Validation dataset size: 39
# -----------------------------------------
# Train dataloader steps:  9
# Val dataloader steps:    3
# ...
