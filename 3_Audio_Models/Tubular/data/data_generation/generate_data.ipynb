# %%
from generate_data import train_TVAE

output_dir = "../../../../project_datasets/audio/tubular"

_, _, _ = train_TVAE(output_dir,
                    epochs= 5000)

# %%
from generate_data import generate_voice_data

output_dir = "../../../../project_datasets/audio/tubular"

df = generate_voice_data(output_dir,
                        file_name= "parkinsons_generated_1",
                        num_generated_samples=100000)
# Out:
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
#
# c:\Users\YOUSSEF\Desktop\Codess & Projects\.venv\lib\site-packages\sdv\_utils.py:500: FutureWarning:
#
# The 'load' function will be deprecated in future versions of SDV. Please use 'utils.load_synthesizer' instead.
# loaded Halthy synthesizer
# loaded PD synthesizer
# loaded Metdata
# Data generated and saved at ../../../../project_datasets/audio/tubular\parkinsons_generated_1.csv
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 23/23 [00:00<00:00, 139.02it/s]|
# Column Shapes Score: 83.06%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 253/253 [00:02<00:00, 88.52it/s]|
# Column Pair Trends Score: 92.87%
#
# Overall Score (Average): 87.97%
#
# Overall Quality Score: 0.8796556104364323
# Detailed Properties:
#              Property     Score
# 0       Column Shapes  0.830607
# 1  Column Pair Trends  0.928704
# -----------------------------------
