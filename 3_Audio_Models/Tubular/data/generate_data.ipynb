# %%
from generate_data import train_TVAE

output_dir = "../../../project_dataset/audio/tubular"

_, _ = train_TVAE(output_dir)

# %%
from generate_data import generate_voice_data

_ = generate_voice_data(output_dir)
